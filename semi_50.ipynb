# %%
'''
Training a semi supervised one layer NMF on 20 news group dataset, with 50% of observing data
'''
# Out:
# '\nTraining a semi supervised one layer NMF on 20 news group dataset, with 50% of observing data\n'

# %%
# import package
import torch
from torch.autograd import Variable
import Ipynb_importer
from deep_nmf import Deep_NMF, Energy_Loss_Func
from writer import Writer
from matplotlib import pyplot as plt
import numpy as np
# Out:
# importing Jupyter notebook from deep_nmf.ipynb
# importing Jupyter notebook from lsqnonneg_module.ipynb
# importing Jupyter notebook from writer.ipynb

# %%
# load the dataset for twenty news
from twenty_news_group_data_loading import data, Y, L20, L50, L90, sparsedata_cr_entr, sparsedata_L2#, get_whole_output
# Out:
# importing Jupyter notebook from twenty_news_group_data_loading.ipynb
# Downloading 20news dataset. This may take a few minutes.
# Downloading dataset from https://ndownloader.figshare.com/files/5975967 (14 MB)

# %%
# Define the network
m = data.shape[1]
k = 20
c = 20
lambd = 100
net = Deep_NMF([m, k], c)
loss_func = Energy_Loss_Func(lambd = lambd, classification_type = 'L2')
dataset = sparsedata_L2(data*1000, Y, L50)

# %%
# Training process!

# setting training parameters
batchsize = 100
epoch = 7
lr_nmf = 5000
lr_cl = 1
loss_lst = []
total_loss_lst = []
# train!
for epo in range(epoch):
    dataloader = torch.utils.data.DataLoader(dataset, batch_size = batchsize, shuffle = True)
    total_loss = 0
    for (i, (inputs, label,l_batch)) in enumerate(dataloader):
        # train the lsqnonneg layers
        inputs = inputs.view([inputs.shape[0], inputs.shape[2]])
        label = label.view([label.shape[0], -1])
        l_batch = l_batch.view([l_batch.shape[0],-1])
        inputs, label = Variable(inputs), Variable(label)
        S_lst,pred = net(inputs)
        loss = loss_func(net, inputs, S_lst,pred,label,l_batch)
        loss.backward()
        loss_lst.append(loss.data)
        total_loss += loss.data
        print('training the nmf layer')
        print(loss.data)
        for A in net.lsqnonneglst.parameters():
            A.data = A.data.sub_(lr_nmf*A.grad.data)
            A.data = A.data.clamp(min = 0)
            A.requires_grad = False
        # train the linear classifier
        print('training the classifier')
        for k in range(10):
            net.zero_grad()
            S_lst,pred = net(inputs)
            loss = loss_func(net, inputs, S_lst,pred,label,l_batch)
            loss.backward()
            print(loss.data)
            for A in net.linear.parameters():
                A.data = A.data.sub_(lr_cl*A.grad.data)
        for A in net.lsqnonneglst.parameters():
            A.requires_grad = True
    print('epoch = ', epo, '\n', total_loss)
    total_loss_lst.append(total_loss)
# Out:
# training the nmf layer
# tensor(9.8788, dtype=torch.float64)
# training the classifier
# tensor(9.8333, dtype=torch.float64)
# tensor(9.8195, dtype=torch.float64)
# tensor(9.8077, dtype=torch.float64)
# tensor(9.7977, dtype=torch.float64)
# tensor(9.7892, dtype=torch.float64)
# tensor(9.7819, dtype=torch.float64)
# tensor(9.7756, dtype=torch.float64)
# tensor(9.7703, dtype=torch.float64)
# tensor(9.7658, dtype=torch.float64)
# tensor(9.7619, dtype=torch.float64)
# training the nmf layer
# tensor(10.0975, dtype=torch.float64)
# training the classifier
# tensor(10.0838, dtype=torch.float64)
# tensor(10.0440, dtype=torch.float64)
# tensor(10.0154, dtype=torch.float64)
# tensor(9.9950, dtype=torch.float64)
# tensor(9.9803, dtype=torch.float64)
# tensor(9.9698, dtype=torch.float64)
# tensor(9.9623, dtype=torch.float64)
# tensor(9.9569, dtype=torch.float64)
# tensor(9.9530, dtype=torch.float64)
# tensor(9.9503, dtype=torch.float64)
# training the nmf layer
# tensor(10.1895, dtype=torch.float64)
# training the classifier
# tensor(10.1777, dtype=torch.float64)
# tensor(10.1591, dtype=torch.float64)
# tensor(10.1443, dtype=torch.float64)
# tensor(10.1325, dtype=torch.float64)
# tensor(10.1231, dtype=torch.float64)
# tensor(10.1156, dtype=torch.float64)
# tensor(10.1097, dtype=torch.float64)
# tensor(10.1050, dtype=torch.float64)
# tensor(10.1012, dtype=torch.float64)
# tensor(10.0982, dtype=torch.float64)
# training the nmf layer
# tensor(10.4053, dtype=torch.float64)
# training the classifier
# tensor(10.3971, dtype=torch.float64)
# tensor(10.3843, dtype=torch.float64)
# tensor(10.3742, dtype=torch.float64)
# tensor(10.3662, dtype=torch.float64)
# tensor(10.3599, dtype=torch.float64)
# tensor(10.3549, dtype=torch.float64)
# tensor(10.3510, dtype=torch.float64)
# tensor(10.3478, dtype=torch.float64)
# tensor(10.3454, dtype=torch.float64)
# tensor(10.3434, dtype=torch.float64)
# training the nmf layer
# tensor(10.0479, dtype=torch.float64)
# training the classifier
# tensor(10.0409, dtype=torch.float64)
# tensor(10.0314, dtype=torch.float64)
# tensor(10.0229, dtype=torch.float64)
# tensor(10.0154, dtype=torch.float64)
# tensor(10.0088, dtype=torch.float64)
# tensor(10.0029, dtype=torch.float64)
# tensor(9.9976, dtype=torch.float64)
# tensor(9.9930, dtype=torch.float64)
# tensor(9.9889, dtype=torch.float64)
# tensor(9.9852, dtype=torch.float64)
# training the nmf layer
# tensor(10.0584, dtype=torch.float64)
# training the classifier
# tensor(10.0598, dtype=torch.float64)
# tensor(10.0461, dtype=torch.float64)
# tensor(10.0359, dtype=torch.float64)
# tensor(10.0283, dtype=torch.float64)
# tensor(10.0226, dtype=torch.float64)
# tensor(10.0184, dtype=torch.float64)
# tensor(10.0152, dtype=torch.float64)
# tensor(10.0129, dtype=torch.float64)
# tensor(10.0111, dtype=torch.float64)
# tensor(10.0098, dtype=torch.float64)
# training the nmf layer
# tensor(10.0539, dtype=torch.float64)
# training the classifier
# tensor(10.0522, dtype=torch.float64)
# tensor(10.0348, dtype=torch.float64)
# tensor(10.0216, dtype=torch.float64)
# tensor(10.0117, dtype=torch.float64)
# tensor(10.0042, dtype=torch.float64)
# tensor(9.9985, dtype=torch.float64)
# tensor(9.9942, dtype=torch.float64)
# tensor(9.9910, dtype=torch.float64)
# tensor(9.9886, dtype=torch.float64)
# tensor(9.9868, dtype=torch.float64)
# training the nmf layer
# tensor(10.4029, dtype=torch.float64)
# training the classifier
# tensor(10.3992, dtype=torch.float64)
# tensor(10.3820, dtype=torch.float64)
# tensor(10.3689, dtype=torch.float64)
# tensor(10.3588, dtype=torch.float64)
# tensor(10.3512, dtype=torch.float64)
# tensor(10.3453, dtype=torch.float64)
# tensor(10.3408, dtype=torch.float64)
# tensor(10.3373, dtype=torch.float64)
# tensor(10.3347, dtype=torch.float64)
# tensor(10.3327, dtype=torch.float64)
# training the nmf layer
# tensor(9.7670, dtype=torch.float64)
# training the classifier
# tensor(9.7642, dtype=torch.float64)
# tensor(9.7557, dtype=torch.float64)
# tensor(9.7488, dtype=torch.float64)
# tensor(9.7433, dtype=torch.float64)
# tensor(9.7388, dtype=torch.float64)
# tensor(9.7352, dtype=torch.float64)
# tensor(9.7323, dtype=torch.float64)
# tensor(9.7300, dtype=torch.float64)
# tensor(9.7281, dtype=torch.float64)
# tensor(9.7266, dtype=torch.float64)
# training the nmf layer
# tensor(10.0014, dtype=torch.float64)
# training the classifier
# tensor(9.9961, dtype=torch.float64)
# tensor(9.9786, dtype=torch.float64)
# tensor(9.9637, dtype=torch.float64)
# tensor(9.9510, dtype=torch.float64)
# tensor(9.9403, dtype=torch.float64)
# tensor(9.9312, dtype=torch.float64)
# tensor(9.9234, dtype=torch.float64)
# tensor(9.9169, dtype=torch.float64)
# tensor(9.9113, dtype=torch.float64)
# tensor(9.9065, dtype=torch.float64)
# training the nmf layer
# tensor(10.0311, dtype=torch.float64)
# training the classifier
# tensor(10.0273, dtype=torch.float64)
# tensor(10.0192, dtype=torch.float64)
# tensor(10.0124, dtype=torch.float64)
# tensor(10.0065, dtype=torch.float64)
# tensor(10.0014, dtype=torch.float64)
# tensor(9.9971, dtype=torch.float64)
# tensor(9.9934, dtype=torch.float64)
# tensor(9.9902, dtype=torch.float64)
# tensor(9.9874, dtype=torch.float64)
# tensor(9.9851, dtype=torch.float64)
# training the nmf layer
# tensor(10.3384, dtype=torch.float64)
# training the classifier
# tensor(10.3331, dtype=torch.float64)
# tensor(10.3261, dtype=torch.float64)
# tensor(10.3207, dtype=torch.float64)
# tensor(10.3164, dtype=torch.float64)
# tensor(10.3130, dtype=torch.float64)
# tensor(10.3104, dtype=torch.float64)
# tensor(10.3083, dtype=torch.float64)
# tensor(10.3067, dtype=torch.float64)
# tensor(10.3054, dtype=torch.float64)
# tensor(10.3045, dtype=torch.float64)
# training the nmf layer
# tensor(10.0514, dtype=torch.float64)
# training the classifier
# tensor(10.0500, dtype=torch.float64)
# tensor(10.0387, dtype=torch.float64)
# tensor(10.0297, dtype=torch.float64)
# tensor(10.0225, dtype=torch.float64)
# tensor(10.0167, dtype=torch.float64)
# tensor(10.0121, dtype=torch.float64)
# tensor(10.0085, dtype=torch.float64)
# tensor(10.0056, dtype=torch.float64)
# tensor(10.0032, dtype=torch.float64)
# tensor(10.0014, dtype=torch.float64)
# training the nmf layer
# tensor(10.2311, dtype=torch.float64)
# training the classifier
# tensor(10.2292, dtype=torch.float64)
# tensor(10.2122, dtype=torch.float64)
# tensor(10.1992, dtype=torch.float64)
# tensor(10.1894, dtype=torch.float64)
# tensor(10.1818, dtype=torch.float64)
# tensor(10.1761, dtype=torch.float64)
# tensor(10.1717, dtype=torch.float64)
# tensor(10.1683, dtype=torch.float64)
# tensor(10.1658, dtype=torch.float64)
# tensor(10.1638, dtype=torch.float64)
# training the nmf layer
# tensor(9.8336, dtype=torch.float64)
# training the classifier
# tensor(9.8291, dtype=torch.float64)
# tensor(9.8212, dtype=torch.float64)
# tensor(9.8145, dtype=torch.float64)
# tensor(9.8088, dtype=torch.float64)
# tensor(9.8040, dtype=torch.float64)
# tensor(9.7999, dtype=torch.float64)
# tensor(9.7965, dtype=torch.float64)
# tensor(9.7935, dtype=torch.float64)
# tensor(9.7911, dtype=torch.float64)
# tensor(9.7890, dtype=torch.float64)
# training the nmf layer
# tensor(10.1710, dtype=torch.float64)
# training the classifier
# tensor(10.1657, dtype=torch.float64)
# tensor(10.1518, dtype=torch.float64)
# tensor(10.1402, dtype=torch.float64)
# tensor(10.1303, dtype=torch.float64)
# tensor(10.1220, dtype=torch.float64)
# tensor(10.1151, dtype=torch.float64)
# tensor(10.1092, dtype=torch.float64)
# tensor(10.1043, dtype=torch.float64)
# tensor(10.1001, dtype=torch.float64)
# tensor(10.0966, dtype=torch.float64)
# training the nmf layer
# tensor(9.7110, dtype=torch.float64)
# training the classifier
# tensor(9.7192, dtype=torch.float64)
# tensor(9.7107, dtype=torch.float64)
# tensor(9.7026, dtype=torch.float64)
# tensor(9.6950, dtype=torch.float64)
# tensor(9.6878, dtype=torch.float64)
# tensor(9.6811, dtype=torch.float64)
# tensor(9.6747, dtype=torch.float64)
# tensor(9.6687, dtype=torch.float64)
# tensor(9.6631, dtype=torch.float64)
# tensor(9.6577, dtype=torch.float64)
# training the nmf layer
# tensor(10.0169, dtype=torch.float64)
# training the classifier
# tensor(10.0300, dtype=torch.float64)
# tensor(10.0048, dtype=torch.float64)
# tensor(9.9857, dtype=torch.float64)
# tensor(9.9712, dtype=torch.float64)
# tensor(9.9603, dtype=torch.float64)
# tensor(9.9520, dtype=torch.float64)
# tensor(9.9457, dtype=torch.float64)
# tensor(9.9409, dtype=torch.float64)
# tensor(9.9373, dtype=torch.float64)
# tensor(9.9345, dtype=torch.float64)
# training the nmf layer
# tensor(9.6954, dtype=torch.float64)
# training the classifier
# tensor(9.6927, dtype=torch.float64)
# tensor(9.6858, dtype=torch.float64)
# tensor(9.6804, dtype=torch.float64)
# tensor(9.6762, dtype=torch.float64)
# tensor(9.6730, dtype=torch.float64)
# tensor(9.6704, dtype=torch.float64)
# tensor(9.6685, dtype=torch.float64)
# tensor(9.6669, dtype=torch.float64)
# tensor(9.6657, dtype=torch.float64)
# tensor(9.6648, dtype=torch.float64)
# training the nmf layer
# tensor(9.5697, dtype=torch.float64)
# training the classifier
# tensor(9.5674, dtype=torch.float64)
# tensor(9.5581, dtype=torch.float64)
# tensor(9.5508, dtype=torch.float64)
# tensor(9.5449, dtype=torch.float64)
# tensor(9.5403, dtype=torch.float64)
# tensor(9.5366, dtype=torch.float64)
# tensor(9.5337, dtype=torch.float64)
# tensor(9.5313, dtype=torch.float64)
# tensor(9.5295, dtype=torch.float64)
# tensor(9.5280, dtype=torch.float64)
# training the nmf layer
# tensor(10.0813, dtype=torch.float64)
# training the classifier
# tensor(10.0629, dtype=torch.float64)
# tensor(10.0497, dtype=torch.float64)
# tensor(10.0385, dtype=torch.float64)
# tensor(10.0288, dtype=torch.float64)
# tensor(10.0205, dtype=torch.float64)
# tensor(10.0133, dtype=torch.float64)
# tensor(10.0071, dtype=torch.float64)
# tensor(10.0017, dtype=torch.float64)
# tensor(9.9971, dtype=torch.float64)
# tensor(9.9930, dtype=torch.float64)
# training the nmf layer
# tensor(10.1588, dtype=torch.float64)
# training the classifier
# tensor(10.1488, dtype=torch.float64)
# tensor(10.1321, dtype=torch.float64)
# tensor(10.1189, dtype=torch.float64)
# tensor(10.1086, dtype=torch.float64)
# tensor(10.1004, dtype=torch.float64)
# tensor(10.0938, dtype=torch.float64)
# tensor(10.0884, dtype=torch.float64)
# tensor(10.0840, dtype=torch.float64)
# tensor(10.0803, dtype=torch.float64)
# tensor(10.0772, dtype=torch.float64)
# training the nmf layer
# tensor(10.1107, dtype=torch.float64)
# training the classifier
# tensor(10.0834, dtype=torch.float64)
# tensor(10.0645, dtype=torch.float64)
# tensor(10.0500, dtype=torch.float64)
# tensor(10.0388, dtype=torch.float64)
# tensor(10.0302, dtype=torch.float64)
# tensor(10.0236, dtype=torch.float64)
# tensor(10.0183, dtype=torch.float64)
# tensor(10.0142, dtype=torch.float64)
# tensor(10.0108, dtype=torch.float64)
# tensor(10.0081, dtype=torch.float64)
# training the nmf layer
# tensor(10.0870, dtype=torch.float64)
# training the classifier
# tensor(10.0945, dtype=torch.float64)
# tensor(10.0694, dtype=torch.float64)
# tensor(10.0506, dtype=torch.float64)
# tensor(10.0363, dtype=torch.float64)
# tensor(10.0253, dtype=torch.float64)
# tensor(10.0168, dtype=torch.float64)
# tensor(10.0102, dtype=torch.float64)
# tensor(10.0048, dtype=torch.float64)
# tensor(10.0005, dtype=torch.float64)
# tensor(9.9969, dtype=torch.float64)
# training the nmf layer
# tensor(9.7303, dtype=torch.float64)
# training the classifier
# tensor(9.7572, dtype=torch.float64)
# tensor(9.7208, dtype=torch.float64)
# tensor(9.6969, dtype=torch.float64)
# tensor(9.6811, dtype=torch.float64)
# tensor(9.6706, dtype=torch.float64)
# tensor(9.6637, dtype=torch.float64)
# tensor(9.6590, dtype=torch.float64)
# tensor(9.6559, dtype=torch.float64)
# tensor(9.6537, dtype=torch.float64)
# tensor(9.6522, dtype=torch.float64)
# training the nmf layer
# tensor(10.5314, dtype=torch.float64)
# training the classifier
# tensor(10.5149, dtype=torch.float64)
# tensor(10.4881, dtype=torch.float64)
# tensor(10.4668, dtype=torch.float64)
# tensor(10.4497, dtype=torch.float64)
# tensor(10.4359, dtype=torch.float64)
# tensor(10.4245, dtype=torch.float64)
# tensor(10.4151, dtype=torch.float64)
# tensor(10.4072, dtype=torch.float64)
# tensor(10.4005, dtype=torch.float64)
# tensor(10.3948, dtype=torch.float64)
# training the nmf layer
# tensor(10.1695, dtype=torch.float64)
# training the classifier
# tensor(10.1494, dtype=torch.float64)
# tensor(10.1241, dtype=torch.float64)
# tensor(10.1042, dtype=torch.float64)
# tensor(10.0884, dtype=torch.float64)
# tensor(10.0759, dtype=torch.float64)
# tensor(10.0657, dtype=torch.float64)
# tensor(10.0574, dtype=torch.float64)
# tensor(10.0506, dtype=torch.float64)
# tensor(10.0448, dtype=torch.float64)
# tensor(10.0399, dtype=torch.float64)
# training the nmf layer
# tensor(9.7774, dtype=torch.float64)
# training the classifier
# tensor(9.7472, dtype=torch.float64)
# tensor(9.7366, dtype=torch.float64)
# tensor(9.7283, dtype=torch.float64)
# tensor(9.7217, dtype=torch.float64)
# tensor(9.7163, dtype=torch.float64)
# tensor(9.7119, dtype=torch.float64)
# tensor(9.7082, dtype=torch.float64)
# tensor(9.7051, dtype=torch.float64)
# tensor(9.7024, dtype=torch.float64)
# tensor(9.7001, dtype=torch.float64)
# training the nmf layer
# tensor(10.2388, dtype=torch.float64)
# training the classifier
# tensor(10.5127, dtype=torch.float64)
# tensor(10.1935, dtype=torch.float64)
# tensor(10.1268, dtype=torch.float64)
# tensor(10.1126, dtype=torch.float64)
# tensor(10.1093, dtype=torch.float64)
# tensor(10.1082, dtype=torch.float64)
# tensor(10.1077, dtype=torch.float64)
# tensor(10.1072, dtype=torch.float64)
# tensor(10.1068, dtype=torch.float64)
# tensor(10.1063, dtype=torch.float64)
# training the nmf layer
# tensor(9.9710, dtype=torch.float64)
# training the classifier
# tensor(9.9185, dtype=torch.float64)
# tensor(9.8676, dtype=torch.float64)
# tensor(9.8401, dtype=torch.float64)
# tensor(9.8244, dtype=torch.float64)
# tensor(9.8148, dtype=torch.float64)
# tensor(9.8083, dtype=torch.float64)
# tensor(9.8036, dtype=torch.float64)
# tensor(9.7998, dtype=torch.float64)
# tensor(9.7966, dtype=torch.float64)
# tensor(9.7938, dtype=torch.float64)
# training the nmf layer
# tensor(9.6040, dtype=torch.float64)
# training the classifier
# tensor(9.5840, dtype=torch.float64)
# tensor(9.5232, dtype=torch.float64)
# tensor(9.4936, dtype=torch.float64)
# tensor(9.4788, dtype=torch.float64)
# tensor(9.4711, dtype=torch.float64)
# tensor(9.4668, dtype=torch.float64)
# tensor(9.4642, dtype=torch.float64)
# tensor(9.4624, dtype=torch.float64)
# tensor(9.4610, dtype=torch.float64)
# tensor(9.4598, dtype=torch.float64)
# training the nmf layer
# tensor(9.9821, dtype=torch.float64)
# training the classifier
# tensor(9.9479, dtype=torch.float64)
# tensor(9.8211, dtype=torch.float64)
# tensor(9.7673, dtype=torch.float64)
# tensor(9.7432, dtype=torch.float64)
# tensor(9.7311, dtype=torch.float64)
# tensor(9.7240, dtype=torch.float64)
# tensor(9.7191, dtype=torch.float64)
# tensor(9.7152, dtype=torch.float64)
# tensor(9.7118, dtype=torch.float64)
# tensor(9.7087, dtype=torch.float64)
# training the nmf layer
# tensor(9.9854, dtype=torch.float64)
# training the classifier
# tensor(10.7450, dtype=torch.float64)
# tensor(9.9235, dtype=torch.float64)
# tensor(9.8225, dtype=torch.float64)
# tensor(9.8100, dtype=torch.float64)
# tensor(9.8085, dtype=torch.float64)
# tensor(9.8083, dtype=torch.float64)
# tensor(9.8083, dtype=torch.float64)
# tensor(9.8083, dtype=torch.float64)
# tensor(9.8083, dtype=torch.float64)
# tensor(9.8083, dtype=torch.float64)
# training the nmf layer
# tensor(9.5743, dtype=torch.float64)
# training the classifier
# tensor(9.5539, dtype=torch.float64)
# tensor(9.4517, dtype=torch.float64)
# tensor(9.4323, dtype=torch.float64)
# tensor(9.4286, dtype=torch.float64)
# tensor(9.4279, dtype=torch.float64)
# tensor(9.4277, dtype=torch.float64)
# tensor(9.4277, dtype=torch.float64)
# tensor(9.4277, dtype=torch.float64)
# tensor(9.4277, dtype=torch.float64)
# tensor(9.4277, dtype=torch.float64)
# training the nmf layer
# tensor(10.2322, dtype=torch.float64)
# training the classifier
# tensor(10.2101, dtype=torch.float64)
# tensor(10.1102, dtype=torch.float64)
# tensor(10.1100, dtype=torch.float64)
# tensor(10.1099, dtype=torch.float64)
# tensor(10.1099, dtype=torch.float64)
# tensor(10.1099, dtype=torch.float64)
# tensor(10.1099, dtype=torch.float64)
# tensor(10.1099, dtype=torch.float64)
# tensor(10.1099, dtype=torch.float64)
# tensor(10.1099, dtype=torch.float64)
# training the nmf layer
# tensor(10.1852, dtype=torch.float64)
# training the classifier
# tensor(10.1219, dtype=torch.float64)
# tensor(10.0699, dtype=torch.float64)
# tensor(10.0580, dtype=torch.float64)
# tensor(10.0553, dtype=torch.float64)
# tensor(10.0546, dtype=torch.float64)
# tensor(10.0545, dtype=torch.float64)
# tensor(10.0545, dtype=torch.float64)
# tensor(10.0545, dtype=torch.float64)
# tensor(10.0545, dtype=torch.float64)
# tensor(10.0545, dtype=torch.float64)
# training the nmf layer
# tensor(9.3342, dtype=torch.float64)
# training the classifier
# tensor(9.2586, dtype=torch.float64)
# tensor(9.1810, dtype=torch.float64)
# tensor(9.1769, dtype=torch.float64)
# tensor(9.1767, dtype=torch.float64)
# tensor(9.1767, dtype=torch.float64)
# tensor(9.1767, dtype=torch.float64)
# tensor(9.1767, dtype=torch.float64)
# tensor(9.1767, dtype=torch.float64)
# tensor(9.1767, dtype=torch.float64)
# tensor(9.1767, dtype=torch.float64)
# training the nmf layer
# tensor(9.8956, dtype=torch.float64)
# training the classifier
# tensor(9.8094, dtype=torch.float64)
# tensor(9.8186, dtype=torch.float64)
# tensor(9.8283, dtype=torch.float64)
# tensor(9.8387, dtype=torch.float64)
# tensor(9.8498, dtype=torch.float64)
# tensor(9.8617, dtype=torch.float64)
# tensor(9.8743, dtype=torch.float64)
# tensor(9.8878, dtype=torch.float64)
# tensor(9.9022, dtype=torch.float64)
# tensor(9.9175, dtype=torch.float64)
# training the nmf layer
# tensor(9.8800, dtype=torch.float64)
# training the classifier
# tensor(9.8272, dtype=torch.float64)
# tensor(10.0891, dtype=torch.float64)
# tensor(10.6156, dtype=torch.float64)
# tensor(11.6736, dtype=torch.float64)
# tensor(13.7999, dtype=torch.float64)
# tensor(18.0734, dtype=torch.float64)
# tensor(26.6623, dtype=torch.float64)
# tensor(43.9239, dtype=torch.float64)
# tensor(78.6162, dtype=torch.float64)
# tensor(148.3402, dtype=torch.float64)
# training the nmf layer
# tensor(245.9384, dtype=torch.float64)
# training the classifier
# tensor(10.0325, dtype=torch.float64)
# tensor(10.0035, dtype=torch.float64)
# tensor(9.9814, dtype=torch.float64)
# tensor(9.9644, dtype=torch.float64)
# tensor(9.9514, dtype=torch.float64)
# tensor(9.9415, dtype=torch.float64)
# tensor(9.9339, dtype=torch.float64)
# tensor(9.9280, dtype=torch.float64)
# tensor(9.9236, dtype=torch.float64)
# tensor(9.9202, dtype=torch.float64)
# training the nmf layer
# tensor(10.0762, dtype=torch.float64)
# training the classifier
# tensor(10.0715, dtype=torch.float64)
# tensor(10.0461, dtype=torch.float64)
# tensor(10.0282, dtype=torch.float64)
# tensor(10.0156, dtype=torch.float64)
# tensor(10.0066, dtype=torch.float64)
# tensor(10.0003, dtype=torch.float64)
# tensor(9.9959, dtype=torch.float64)
# tensor(9.9927, dtype=torch.float64)
# tensor(9.9905, dtype=torch.float64)
# tensor(9.9889, dtype=torch.float64)
# training the nmf layer
# tensor(10.0662, dtype=torch.float64)
# training the classifier
# tensor(10.0623, dtype=torch.float64)
# tensor(10.0386, dtype=torch.float64)
# tensor(10.0216, dtype=torch.float64)
# tensor(10.0095, dtype=torch.float64)
# tensor(10.0008, dtype=torch.float64)
# tensor(9.9946, dtype=torch.float64)
# tensor(9.9902, dtype=torch.float64)
# tensor(9.9870, dtype=torch.float64)
# tensor(9.9848, dtype=torch.float64)
# tensor(9.9831, dtype=torch.float64)
# training the nmf layer
# tensor(10.0100, dtype=torch.float64)
# training the classifier
# tensor(10.0057, dtype=torch.float64)
# tensor(9.9846, dtype=torch.float64)
# tensor(9.9697, dtype=torch.float64)
# tensor(9.9593, dtype=torch.float64)
# tensor(9.9519, dtype=torch.float64)
# tensor(9.9468, dtype=torch.float64)
# tensor(9.9431, dtype=torch.float64)
# tensor(9.9406, dtype=torch.float64)
# tensor(9.9388, dtype=torch.float64)
# tensor(9.9375, dtype=torch.float64)
# training the nmf layer
# tensor(10.0281, dtype=torch.float64)
# training the classifier
# tensor(10.0236, dtype=torch.float64)
# tensor(10.0048, dtype=torch.float64)
# tensor(9.9915, dtype=torch.float64)
# tensor(9.9820, dtype=torch.float64)
# tensor(9.9752, dtype=torch.float64)
# tensor(9.9704, dtype=torch.float64)
# tensor(9.9670, dtype=torch.float64)
# tensor(9.9646, dtype=torch.float64)
# tensor(9.9629, dtype=torch.float64)
# tensor(9.9616, dtype=torch.float64)
# training the nmf layer
# tensor(9.9892, dtype=torch.float64)
# training the classifier
# tensor(9.9815, dtype=torch.float64)
# tensor(9.9636, dtype=torch.float64)
# tensor(9.9522, dtype=torch.float64)
# tensor(9.9450, dtype=torch.float64)
# tensor(9.9404, dtype=torch.float64)
# tensor(9.9375, dtype=torch.float64)
# tensor(9.9356, dtype=torch.float64)
# tensor(9.9345, dtype=torch.float64)
# tensor(9.9337, dtype=torch.float64)
# tensor(9.9332, dtype=torch.float64)
# training the nmf layer
# tensor(9.8029, dtype=torch.float64)
# training the classifier
# tensor(9.8000, dtype=torch.float64)
# tensor(9.7685, dtype=torch.float64)
# tensor(9.7495, dtype=torch.float64)
# tensor(9.7381, dtype=torch.float64)
# tensor(9.7312, dtype=torch.float64)
# tensor(9.7271, dtype=torch.float64)
# tensor(9.7246, dtype=torch.float64)
# tensor(9.7231, dtype=torch.float64)
# tensor(9.7222, dtype=torch.float64)
# tensor(9.7216, dtype=torch.float64)
# training the nmf layer
# tensor(10.1255, dtype=torch.float64)
# training the classifier
# tensor(10.1226, dtype=torch.float64)
# tensor(10.0834, dtype=torch.float64)
# tensor(10.0605, dtype=torch.float64)
# tensor(10.0471, dtype=torch.float64)
# tensor(10.0393, dtype=torch.float64)
# tensor(10.0348, dtype=torch.float64)
# tensor(10.0321, dtype=torch.float64)
# tensor(10.0305, dtype=torch.float64)
# tensor(10.0296, dtype=torch.float64)
# tensor(10.0291, dtype=torch.float64)
# training the nmf layer
# tensor(9.8943, dtype=torch.float64)
# training the classifier
# tensor(9.8868, dtype=torch.float64)
# tensor(9.8396, dtype=torch.float64)
# tensor(9.8129, dtype=torch.float64)
# tensor(9.7977, dtype=torch.float64)
# tensor(9.7890, dtype=torch.float64)
# tensor(9.7841, dtype=torch.float64)
# tensor(9.7813, dtype=torch.float64)
# tensor(9.7797, dtype=torch.float64)
# tensor(9.7788, dtype=torch.float64)
# tensor(9.7783, dtype=torch.float64)
# training the nmf layer
# tensor(10.0616, dtype=torch.float64)
# training the classifier
# tensor(10.0536, dtype=torch.float64)
# tensor(10.0155, dtype=torch.float64)
# tensor(9.9912, dtype=torch.float64)
# tensor(9.9757, dtype=torch.float64)
# tensor(9.9658, dtype=torch.float64)
# tensor(9.9595, dtype=torch.float64)
# tensor(9.9555, dtype=torch.float64)
# tensor(9.9530, dtype=torch.float64)
# tensor(9.9514, dtype=torch.float64)
# tensor(9.9503, dtype=torch.float64)
# training the nmf layer
# tensor(9.8206, dtype=torch.float64)
# training the classifier
# tensor(9.8111, dtype=torch.float64)
# tensor(9.7843, dtype=torch.float64)
# tensor(9.7704, dtype=torch.float64)
# tensor(9.7632, dtype=torch.float64)
# tensor(9.7594, dtype=torch.float64)
# tensor(9.7575, dtype=torch.float64)
# tensor(9.7565, dtype=torch.float64)
# tensor(9.7559, dtype=torch.float64)
# tensor(9.7557, dtype=torch.float64)
# tensor(9.7555, dtype=torch.float64)
# training the nmf layer
# tensor(10.0971, dtype=torch.float64)
# training the classifier
# tensor(10.0933, dtype=torch.float64)
# tensor(10.0112, dtype=torch.float64)
# tensor(9.9665, dtype=torch.float64)
# tensor(9.9422, dtype=torch.float64)
# tensor(9.9289, dtype=torch.float64)
# tensor(9.9218, dtype=torch.float64)
# tensor(9.9178, dtype=torch.float64)
# tensor(9.9157, dtype=torch.float64)
# tensor(9.9145, dtype=torch.float64)
# tensor(9.9139, dtype=torch.float64)
# training the nmf layer
# tensor(10.2349, dtype=torch.float64)
# training the classifier
# tensor(10.2310, dtype=torch.float64)
# tensor(10.1985, dtype=torch.float64)
# tensor(10.1816, dtype=torch.float64)
# tensor(10.1728, dtype=torch.float64)
# tensor(10.1682, dtype=torch.float64)
# tensor(10.1658, dtype=torch.float64)
# tensor(10.1645, dtype=torch.float64)
# tensor(10.1638, dtype=torch.float64)
# tensor(10.1635, dtype=torch.float64)
# tensor(10.1633, dtype=torch.float64)
# training the nmf layer
# tensor(9.6008, dtype=torch.float64)
# training the classifier
# tensor(9.5900, dtype=torch.float64)
# tensor(9.5717, dtype=torch.float64)
# tensor(9.5606, dtype=torch.float64)
# tensor(9.5540, dtype=torch.float64)
# tensor(9.5500, dtype=torch.float64)
# tensor(9.5475, dtype=torch.float64)
# tensor(9.5461, dtype=torch.float64)
# tensor(9.5452, dtype=torch.float64)
# tensor(9.5447, dtype=torch.float64)
# tensor(9.5443, dtype=torch.float64)
# training the nmf layer
# tensor(10.2616, dtype=torch.float64)
# training the classifier
# tensor(10.2582, dtype=torch.float64)
# tensor(10.2070, dtype=torch.float64)
# tensor(10.1886, dtype=torch.float64)
# tensor(10.1820, dtype=torch.float64)
# tensor(10.1796, dtype=torch.float64)
# tensor(10.1788, dtype=torch.float64)
# tensor(10.1785, dtype=torch.float64)
# tensor(10.1784, dtype=torch.float64)
# tensor(10.1783, dtype=torch.float64)
# tensor(10.1783, dtype=torch.float64)
# training the nmf layer
# tensor(9.8334, dtype=torch.float64)
# training the classifier
# tensor(9.8242, dtype=torch.float64)
# tensor(9.7628, dtype=torch.float64)
# tensor(9.7401, dtype=torch.float64)
# tensor(9.7316, dtype=torch.float64)
# tensor(9.7285, dtype=torch.float64)
# tensor(9.7273, dtype=torch.float64)
# tensor(9.7269, dtype=torch.float64)
# tensor(9.7267, dtype=torch.float64)
# tensor(9.7266, dtype=torch.float64)
# tensor(9.7266, dtype=torch.float64)
# training the nmf layer
# tensor(10.1015, dtype=torch.float64)
# training the classifier
# tensor(10.0974, dtype=torch.float64)
# tensor(10.0032, dtype=torch.float64)
# tensor(9.9735, dtype=torch.float64)
# tensor(9.9642, dtype=torch.float64)
# tensor(9.9612, dtype=torch.float64)
# tensor(9.9603, dtype=torch.float64)
# tensor(9.9600, dtype=torch.float64)
# tensor(9.9599, dtype=torch.float64)
# tensor(9.9599, dtype=torch.float64)
# tensor(9.9599, dtype=torch.float64)
# training the nmf layer
# tensor(9.8831, dtype=torch.float64)
# training the classifier
# tensor(9.8764, dtype=torch.float64)
# tensor(9.7992, dtype=torch.float64)
# tensor(9.7777, dtype=torch.float64)
# tensor(9.7717, dtype=torch.float64)
# tensor(9.7700, dtype=torch.float64)
# tensor(9.7696, dtype=torch.float64)
# tensor(9.7694, dtype=torch.float64)
# tensor(9.7694, dtype=torch.float64)
# tensor(9.7694, dtype=torch.float64)
# tensor(9.7694, dtype=torch.float64)
# training the nmf layer
# tensor(9.9380, dtype=torch.float64)
# training the classifier
# tensor(9.9289, dtype=torch.float64)
# tensor(9.7791, dtype=torch.float64)
# tensor(9.7538, dtype=torch.float64)
# tensor(9.7495, dtype=torch.float64)
# tensor(9.7488, dtype=torch.float64)
# tensor(9.7487, dtype=torch.float64)
# tensor(9.7486, dtype=torch.float64)
# tensor(9.7486, dtype=torch.float64)
# tensor(9.7486, dtype=torch.float64)
# tensor(9.7486, dtype=torch.float64)
# training the nmf layer
# tensor(9.8478, dtype=torch.float64)
# training the classifier
# tensor(9.8333, dtype=torch.float64)
# tensor(9.7277, dtype=torch.float64)
# tensor(9.7168, dtype=torch.float64)
# tensor(9.7157, dtype=torch.float64)
# tensor(9.7155, dtype=torch.float64)
# tensor(9.7155, dtype=torch.float64)
# tensor(9.7155, dtype=torch.float64)
# tensor(9.7155, dtype=torch.float64)
# tensor(9.7155, dtype=torch.float64)
# tensor(9.7155, dtype=torch.float64)
# training the nmf layer
# tensor(9.9475, dtype=torch.float64)
# training the classifier
# tensor(9.9150, dtype=torch.float64)
# tensor(9.8520, dtype=torch.float64)
# tensor(9.8486, dtype=torch.float64)
# tensor(9.8484, dtype=torch.float64)
# tensor(9.8484, dtype=torch.float64)
# tensor(9.8484, dtype=torch.float64)
# tensor(9.8484, dtype=torch.float64)
# tensor(9.8484, dtype=torch.float64)
# tensor(9.8484, dtype=torch.float64)
# tensor(9.8484, dtype=torch.float64)
# training the nmf layer
# tensor(10.1223, dtype=torch.float64)
# training the classifier
# tensor(10.0847, dtype=torch.float64)
# tensor(9.9223, dtype=torch.float64)
# tensor(9.9205, dtype=torch.float64)
# tensor(9.9204, dtype=torch.float64)
# tensor(9.9204, dtype=torch.float64)
# tensor(9.9204, dtype=torch.float64)
# tensor(9.9204, dtype=torch.float64)
# tensor(9.9204, dtype=torch.float64)
# tensor(9.9204, dtype=torch.float64)
# tensor(9.9204, dtype=torch.float64)
# training the nmf layer
# tensor(10.1524, dtype=torch.float64)
# training the classifier
# tensor(10.0964, dtype=torch.float64)
# tensor(10.0392, dtype=torch.float64)
# tensor(10.0223, dtype=torch.float64)
# tensor(10.0174, dtype=torch.float64)
# tensor(10.0160, dtype=torch.float64)
# tensor(10.0155, dtype=torch.float64)
# tensor(10.0154, dtype=torch.float64)
# tensor(10.0154, dtype=torch.float64)
# tensor(10.0154, dtype=torch.float64)
# tensor(10.0154, dtype=torch.float64)
# training the nmf layer
# tensor(10.1619, dtype=torch.float64)
# training the classifier
# tensor(10.0909, dtype=torch.float64)
# tensor(10.0681, dtype=torch.float64)
# tensor(10.0497, dtype=torch.float64)
# tensor(10.0349, dtype=torch.float64)
# tensor(10.0229, dtype=torch.float64)
# tensor(10.0132, dtype=torch.float64)
# tensor(10.0053, dtype=torch.float64)
# tensor(9.9990, dtype=torch.float64)
# tensor(9.9938, dtype=torch.float64)
# tensor(9.9897, dtype=torch.float64)
# training the nmf layer
# tensor(10.4036, dtype=torch.float64)
# training the classifier
# tensor(10.3274, dtype=torch.float64)
# tensor(10.5154, dtype=torch.float64)
# tensor(10.9857, dtype=torch.float64)
# tensor(12.1620, dtype=torch.float64)
# tensor(15.1043, dtype=torch.float64)
# tensor(22.4634, dtype=torch.float64)
# tensor(40.8702, dtype=torch.float64)
# tensor(86.9094, dtype=torch.float64)
# tensor(202.0636, dtype=torch.float64)
# tensor(490.0890, dtype=torch.float64)
# training the nmf layer
# tensor(862.7394, dtype=torch.float64)
# training the classifier
# tensor(10.0810, dtype=torch.float64)
# tensor(10.0787, dtype=torch.float64)
# tensor(10.0765, dtype=torch.float64)
# tensor(10.0742, dtype=torch.float64)
# tensor(10.0720, dtype=torch.float64)
# tensor(10.0698, dtype=torch.float64)
# tensor(10.0676, dtype=torch.float64)
# tensor(10.0655, dtype=torch.float64)
# tensor(10.0634, dtype=torch.float64)
# tensor(10.0613, dtype=torch.float64)
# training the nmf layer
# tensor(10.3190, dtype=torch.float64)
# training the classifier
# tensor(10.2808, dtype=torch.float64)
# tensor(10.2639, dtype=torch.float64)
# tensor(10.2488, dtype=torch.float64)
# tensor(10.2355, dtype=torch.float64)
# tensor(10.2237, dtype=torch.float64)
# tensor(10.2132, dtype=torch.float64)
# tensor(10.2039, dtype=torch.float64)
# tensor(10.1956, dtype=torch.float64)
# tensor(10.1882, dtype=torch.float64)
# tensor(10.1816, dtype=torch.float64)
# training the nmf layer
# tensor(9.9813, dtype=torch.float64)
# training the classifier
# tensor(9.9457, dtype=torch.float64)
# tensor(9.9223, dtype=torch.float64)
# tensor(9.9064, dtype=torch.float64)
# tensor(9.8957, dtype=torch.float64)
# tensor(9.8884, dtype=torch.float64)
# tensor(9.8834, dtype=torch.float64)
# tensor(9.8800, dtype=torch.float64)
# tensor(9.8776, dtype=torch.float64)
# tensor(9.8760, dtype=torch.float64)
# tensor(9.8749, dtype=torch.float64)
# training the nmf layer
# tensor(9.8472, dtype=torch.float64)
# training the classifier
# tensor(9.8439, dtype=torch.float64)
# tensor(9.8164, dtype=torch.float64)
# tensor(9.7960, dtype=torch.float64)
# tensor(9.7807, dtype=torch.float64)
# tensor(9.7693, dtype=torch.float64)
# tensor(9.7608, dtype=torch.float64)
# tensor(9.7545, dtype=torch.float64)
# tensor(9.7498, dtype=torch.float64)
# tensor(9.7462, dtype=torch.float64)
# tensor(9.7436, dtype=torch.float64)
# training the nmf layer
# tensor(9.8207, dtype=torch.float64)
# training the classifier
# tensor(9.8049, dtype=torch.float64)
# tensor(9.7863, dtype=torch.float64)
# tensor(9.7711, dtype=torch.float64)
# tensor(9.7587, dtype=torch.float64)
# tensor(9.7485, dtype=torch.float64)
# tensor(9.7402, dtype=torch.float64)
# tensor(9.7334, dtype=torch.float64)
# tensor(9.7278, dtype=torch.float64)
# tensor(9.7233, dtype=torch.float64)
# tensor(9.7196, dtype=torch.float64)
# training the nmf layer
# tensor(10.2962, dtype=torch.float64)
# training the classifier
# tensor(10.2797, dtype=torch.float64)
# tensor(10.2642, dtype=torch.float64)
# tensor(10.2526, dtype=torch.float64)
# tensor(10.2437, dtype=torch.float64)
# tensor(10.2371, dtype=torch.float64)
# tensor(10.2320, dtype=torch.float64)
# tensor(10.2281, dtype=torch.float64)
# tensor(10.2251, dtype=torch.float64)
# tensor(10.2228, dtype=torch.float64)
# tensor(10.2210, dtype=torch.float64)
# training the nmf layer
# tensor(10.1730, dtype=torch.float64)
# training the classifier
# tensor(10.1340, dtype=torch.float64)
# tensor(10.1249, dtype=torch.float64)
# tensor(10.1167, dtype=torch.float64)
# tensor(10.1093, dtype=torch.float64)
# tensor(10.1026, dtype=torch.float64)
# tensor(10.0965, dtype=torch.float64)
# tensor(10.0910, dtype=torch.float64)
# tensor(10.0859, dtype=torch.float64)
# tensor(10.0814, dtype=torch.float64)
# tensor(10.0772, dtype=torch.float64)
# training the nmf layer
# tensor(9.8321, dtype=torch.float64)
# training the classifier
# tensor(9.8150, dtype=torch.float64)
# tensor(9.7954, dtype=torch.float64)
# tensor(9.7802, dtype=torch.float64)
# tensor(9.7685, dtype=torch.float64)
# tensor(9.7594, dtype=torch.float64)
# tensor(9.7523, dtype=torch.float64)
# tensor(9.7468, dtype=torch.float64)
# tensor(9.7424, dtype=torch.float64)
# tensor(9.7389, dtype=torch.float64)
# tensor(9.7362, dtype=torch.float64)
# training the nmf layer
# tensor(10.0088, dtype=torch.float64)
# training the classifier
# tensor(9.9855, dtype=torch.float64)
# tensor(9.9750, dtype=torch.float64)
# tensor(9.9665, dtype=torch.float64)
# tensor(9.9597, dtype=torch.float64)
# tensor(9.9541, dtype=torch.float64)
# tensor(9.9496, dtype=torch.float64)
# tensor(9.9459, dtype=torch.float64)
# tensor(9.9429, dtype=torch.float64)
# tensor(9.9404, dtype=torch.float64)
# tensor(9.9383, dtype=torch.float64)
# training the nmf layer
# tensor(10.3073, dtype=torch.float64)
# training the classifier
# tensor(10.2670, dtype=torch.float64)
# tensor(10.2501, dtype=torch.float64)
# tensor(10.2357, dtype=torch.float64)
# tensor(10.2235, dtype=torch.float64)
# tensor(10.2131, dtype=torch.float64)
# tensor(10.2043, dtype=torch.float64)
# tensor(10.1968, dtype=torch.float64)
# tensor(10.1903, dtype=torch.float64)
# tensor(10.1848, dtype=torch.float64)
# tensor(10.1801, dtype=torch.float64)
# training the nmf layer
# tensor(9.8958, dtype=torch.float64)
# training the classifier
# tensor(9.9218, dtype=torch.float64)
# tensor(9.9025, dtype=torch.float64)
# tensor(9.8865, dtype=torch.float64)
# tensor(9.8732, dtype=torch.float64)
# tensor(9.8622, dtype=torch.float64)
# tensor(9.8530, dtype=torch.float64)
# tensor(9.8453, dtype=torch.float64)
# tensor(9.8388, dtype=torch.float64)
# tensor(9.8332, dtype=torch.float64)
# tensor(9.8284, dtype=torch.float64)
# training the nmf layer
# tensor(9.9878, dtype=torch.float64)
# training the classifier
# tensor(10.4966, dtype=torch.float64)
# tensor(10.0224, dtype=torch.float64)
# tensor(9.9081, dtype=torch.float64)
# tensor(9.8806, dtype=torch.float64)
# tensor(9.8739, dtype=torch.float64)
# tensor(9.8723, dtype=torch.float64)
# tensor(9.8718, dtype=torch.float64)
# tensor(9.8716, dtype=torch.float64)
# tensor(9.8716, dtype=torch.float64)
# tensor(9.8715, dtype=torch.float64)
# training the nmf layer
# tensor(10.0512, dtype=torch.float64)
# training the classifier
# tensor(10.0193, dtype=torch.float64)
# tensor(9.9712, dtype=torch.float64)
# tensor(9.9649, dtype=torch.float64)
# tensor(9.9640, dtype=torch.float64)
# tensor(9.9637, dtype=torch.float64)
# tensor(9.9635, dtype=torch.float64)
# tensor(9.9633, dtype=torch.float64)
# tensor(9.9631, dtype=torch.float64)
# tensor(9.9629, dtype=torch.float64)
# tensor(9.9628, dtype=torch.float64)
# training the nmf layer
# tensor(10.0327, dtype=torch.float64)
# training the classifier
# tensor(9.9965, dtype=torch.float64)
# tensor(9.9104, dtype=torch.float64)
# tensor(9.9102, dtype=torch.float64)
# tensor(9.9101, dtype=torch.float64)
# tensor(9.9100, dtype=torch.float64)
# tensor(9.9099, dtype=torch.float64)
# tensor(9.9097, dtype=torch.float64)
# tensor(9.9096, dtype=torch.float64)
# tensor(9.9095, dtype=torch.float64)
# tensor(9.9094, dtype=torch.float64)
# training the nmf layer
# tensor(10.2821, dtype=torch.float64)
# training the classifier
# tensor(10.2412, dtype=torch.float64)
# tensor(10.1310, dtype=torch.float64)
# tensor(10.1261, dtype=torch.float64)
# tensor(10.1259, dtype=torch.float64)
# tensor(10.1259, dtype=torch.float64)
# tensor(10.1259, dtype=torch.float64)
# tensor(10.1259, dtype=torch.float64)
# tensor(10.1259, dtype=torch.float64)
# tensor(10.1259, dtype=torch.float64)
# tensor(10.1259, dtype=torch.float64)
# training the nmf layer
# tensor(9.8278, dtype=torch.float64)
# training the classifier
# tensor(9.7605, dtype=torch.float64)
# tensor(9.6582, dtype=torch.float64)
# tensor(9.6341, dtype=torch.float64)
# tensor(9.6285, dtype=torch.float64)
# tensor(9.6271, dtype=torch.float64)
# tensor(9.6268, dtype=torch.float64)
# tensor(9.6268, dtype=torch.float64)
# tensor(9.6267, dtype=torch.float64)
# tensor(9.6267, dtype=torch.float64)
# tensor(9.6267, dtype=torch.float64)
# training the nmf layer
# tensor(9.6583, dtype=torch.float64)
# training the classifier
# tensor(9.5687, dtype=torch.float64)
# tensor(9.5161, dtype=torch.float64)
# tensor(9.5031, dtype=torch.float64)
# tensor(9.4998, dtype=torch.float64)
# tensor(9.4989, dtype=torch.float64)
# tensor(9.4986, dtype=torch.float64)
# tensor(9.4984, dtype=torch.float64)
# tensor(9.4983, dtype=torch.float64)
# tensor(9.4982, dtype=torch.float64)
# tensor(9.4980, dtype=torch.float64)
# training the nmf layer
# tensor(9.2687, dtype=torch.float64)
# training the classifier
# tensor(9.1437, dtype=torch.float64)
# tensor(9.0998, dtype=torch.float64)
# tensor(9.0794, dtype=torch.float64)
# tensor(9.0699, dtype=torch.float64)
# tensor(9.0655, dtype=torch.float64)
# tensor(9.0634, dtype=torch.float64)
# tensor(9.0624, dtype=torch.float64)
# tensor(9.0618, dtype=torch.float64)
# tensor(9.0615, dtype=torch.float64)
# tensor(9.0613, dtype=torch.float64)
# training the nmf layer
# tensor(9.3453, dtype=torch.float64)
# training the classifier
# tensor(9.2190, dtype=torch.float64)
# tensor(9.2924, dtype=torch.float64)
# tensor(9.4110, dtype=torch.float64)
# tensor(9.6023, dtype=torch.float64)
# tensor(9.9112, dtype=torch.float64)
# tensor(10.4097, dtype=torch.float64)
# tensor(11.2142, dtype=torch.float64)
# tensor(12.5128, dtype=torch.float64)
# tensor(14.6087, dtype=torch.float64)
# tensor(17.9914, dtype=torch.float64)
# training the nmf layer
# tensor(25.9209, dtype=torch.float64)
# training the classifier
# tensor(9.9956, dtype=torch.float64)
# tensor(9.9817, dtype=torch.float64)
# tensor(9.9691, dtype=torch.float64)
# tensor(9.9576, dtype=torch.float64)
# tensor(9.9470, dtype=torch.float64)
# tensor(9.9374, dtype=torch.float64)
# tensor(9.9285, dtype=torch.float64)
# tensor(9.9204, dtype=torch.float64)
# tensor(9.9131, dtype=torch.float64)
# tensor(9.9063, dtype=torch.float64)
# training the nmf layer
# tensor(9.9728, dtype=torch.float64)
# training the classifier
# tensor(9.9657, dtype=torch.float64)
# tensor(9.9538, dtype=torch.float64)
# tensor(9.9440, dtype=torch.float64)
# tensor(9.9358, dtype=torch.float64)
# tensor(9.9291, dtype=torch.float64)
# tensor(9.9235, dtype=torch.float64)
# tensor(9.9189, dtype=torch.float64)
# tensor(9.9151, dtype=torch.float64)
# tensor(9.9119, dtype=torch.float64)
# tensor(9.9093, dtype=torch.float64)
# training the nmf layer
# tensor(9.6328, dtype=torch.float64)
# training the classifier
# tensor(9.6268, dtype=torch.float64)
# tensor(9.6204, dtype=torch.float64)
# tensor(9.6150, dtype=torch.float64)
# tensor(9.6103, dtype=torch.float64)
# tensor(9.6063, dtype=torch.float64)
# tensor(9.6028, dtype=torch.float64)
# tensor(9.5999, dtype=torch.float64)
# tensor(9.5974, dtype=torch.float64)
# tensor(9.5952, dtype=torch.float64)
# tensor(9.5934, dtype=torch.float64)
# training the nmf layer
# tensor(9.6768, dtype=torch.float64)
# training the classifier
# tensor(9.6734, dtype=torch.float64)
# tensor(9.6637, dtype=torch.float64)
# tensor(9.6555, dtype=torch.float64)
# tensor(9.6485, dtype=torch.float64)
# tensor(9.6427, dtype=torch.float64)
# tensor(9.6377, dtype=torch.float64)
# tensor(9.6335, dtype=torch.float64)
# tensor(9.6300, dtype=torch.float64)
# tensor(9.6269, dtype=torch.float64)
# tensor(9.6244, dtype=torch.float64)
# training the nmf layer
# tensor(9.9474, dtype=torch.float64)
# training the classifier
# tensor(9.9406, dtype=torch.float64)
# tensor(9.9310, dtype=torch.float64)
# tensor(9.9224, dtype=torch.float64)
# tensor(9.9146, dtype=torch.float64)
# tensor(9.9077, dtype=torch.float64)
# tensor(9.9015, dtype=torch.float64)
# tensor(9.8959, dtype=torch.float64)
# tensor(9.8909, dtype=torch.float64)
# tensor(9.8864, dtype=torch.float64)
# tensor(9.8823, dtype=torch.float64)
# training the nmf layer
# tensor(9.7085, dtype=torch.float64)
# training the classifier
# tensor(9.6958, dtype=torch.float64)
# tensor(9.6861, dtype=torch.float64)
# tensor(9.6775, dtype=torch.float64)
# tensor(9.6698, dtype=torch.float64)
# tensor(9.6629, dtype=torch.float64)
# tensor(9.6567, dtype=torch.float64)
# tensor(9.6511, dtype=torch.float64)
# tensor(9.6462, dtype=torch.float64)
# tensor(9.6417, dtype=torch.float64)
# tensor(9.6377, dtype=torch.float64)
# training the nmf layer
# tensor(9.8587, dtype=torch.float64)
# training the classifier
# tensor(9.8491, dtype=torch.float64)
# tensor(9.8439, dtype=torch.float64)
# tensor(9.8390, dtype=torch.float64)
# tensor(9.8346, dtype=torch.float64)
# tensor(9.8305, dtype=torch.float64)
# tensor(9.8267, dtype=torch.float64)
# tensor(9.8231, dtype=torch.float64)
# tensor(9.8199, dtype=torch.float64)
# tensor(9.8168, dtype=torch.float64)
# tensor(9.8140, dtype=torch.float64)
# training the nmf layer
# tensor(10.2660, dtype=torch.float64)
# training the classifier
# tensor(10.2578, dtype=torch.float64)
# tensor(10.2403, dtype=torch.float64)
# tensor(10.2265, dtype=torch.float64)
# tensor(10.2155, dtype=torch.float64)
# tensor(10.2067, dtype=torch.float64)
# tensor(10.1997, dtype=torch.float64)
# tensor(10.1939, dtype=torch.float64)
# tensor(10.1892, dtype=torch.float64)
# tensor(10.1852, dtype=torch.float64)
# tensor(10.1818, dtype=torch.float64)
# training the nmf layer
# tensor(9.8795, dtype=torch.float64)
# training the classifier
# tensor(9.8633, dtype=torch.float64)
# tensor(9.8491, dtype=torch.float64)
# tensor(9.8365, dtype=torch.float64)
# tensor(9.8253, dtype=torch.float64)
# tensor(9.8154, dtype=torch.float64)
# tensor(9.8065, dtype=torch.float64)
# tensor(9.7986, dtype=torch.float64)
# tensor(9.7915, dtype=torch.float64)
# tensor(9.7852, dtype=torch.float64)
# tensor(9.7795, dtype=torch.float64)
# training the nmf layer
# tensor(10.0117, dtype=torch.float64)
# training the classifier
# tensor(10.0292, dtype=torch.float64)
# tensor(10.0043, dtype=torch.float64)
# tensor(9.9863, dtype=torch.float64)
# tensor(9.9733, dtype=torch.float64)
# tensor(9.9638, dtype=torch.float64)
# tensor(9.9569, dtype=torch.float64)
# tensor(9.9517, dtype=torch.float64)
# tensor(9.9478, dtype=torch.float64)
# tensor(9.9449, dtype=torch.float64)
# tensor(9.9426, dtype=torch.float64)
# training the nmf layer
# tensor(10.1038, dtype=torch.float64)
# training the classifier
# tensor(10.2467, dtype=torch.float64)
# tensor(10.1458, dtype=torch.float64)
# tensor(10.0755, dtype=torch.float64)
# tensor(10.0264, dtype=torch.float64)
# tensor(9.9921, dtype=torch.float64)
# tensor(9.9680, dtype=torch.float64)
# tensor(9.9509, dtype=torch.float64)
# tensor(9.9388, dtype=torch.float64)
# tensor(9.9301, dtype=torch.float64)
# tensor(9.9238, dtype=torch.float64)
# training the nmf layer
# tensor(10.2337, dtype=torch.float64)
# training the classifier
# tensor(10.2145, dtype=torch.float64)
# tensor(10.1982, dtype=torch.float64)
# tensor(10.1852, dtype=torch.float64)
# tensor(10.1748, dtype=torch.float64)
# tensor(10.1664, dtype=torch.float64)
# tensor(10.1595, dtype=torch.float64)
# tensor(10.1539, dtype=torch.float64)
# tensor(10.1493, dtype=torch.float64)
# tensor(10.1453, dtype=torch.float64)
# tensor(10.1420, dtype=torch.float64)
# training the nmf layer
# tensor(9.8160, dtype=torch.float64)
# training the classifier
# tensor(9.8394, dtype=torch.float64)
# tensor(9.8125, dtype=torch.float64)
# tensor(9.7920, dtype=torch.float64)
# tensor(9.7763, dtype=torch.float64)
# tensor(9.7643, dtype=torch.float64)
# tensor(9.7551, dtype=torch.float64)
# tensor(9.7478, dtype=torch.float64)
# tensor(9.7422, dtype=torch.float64)
# tensor(9.7377, dtype=torch.float64)
# tensor(9.7341, dtype=torch.float64)
# training the nmf layer
# tensor(10.4402, dtype=torch.float64)
# training the classifier
# tensor(10.5381, dtype=torch.float64)
# tensor(10.4425, dtype=torch.float64)
# tensor(10.3947, dtype=torch.float64)
# tensor(10.3709, dtype=torch.float64)
# tensor(10.3589, dtype=torch.float64)
# tensor(10.3529, dtype=torch.float64)
# tensor(10.3499, dtype=torch.float64)
# tensor(10.3484, dtype=torch.float64)
# tensor(10.3476, dtype=torch.float64)
# tensor(10.3472, dtype=torch.float64)
# training the nmf layer
# tensor(9.6396, dtype=torch.float64)
# training the classifier
# tensor(9.6302, dtype=torch.float64)
# tensor(9.6097, dtype=torch.float64)
# tensor(9.5978, dtype=torch.float64)
# tensor(9.5908, dtype=torch.float64)
# tensor(9.5867, dtype=torch.float64)
# tensor(9.5843, dtype=torch.float64)
# tensor(9.5829, dtype=torch.float64)
# tensor(9.5820, dtype=torch.float64)
# tensor(9.5815, dtype=torch.float64)
# tensor(9.5811, dtype=torch.float64)
# training the nmf layer
# tensor(10.0580, dtype=torch.float64)
# training the classifier
# tensor(10.0541, dtype=torch.float64)
# tensor(10.0002, dtype=torch.float64)
# tensor(9.9746, dtype=torch.float64)
# tensor(9.9626, dtype=torch.float64)
# tensor(9.9568, dtype=torch.float64)
# tensor(9.9541, dtype=torch.float64)
# tensor(9.9528, dtype=torch.float64)
# tensor(9.9521, dtype=torch.float64)
# tensor(9.9518, dtype=torch.float64)
# tensor(9.9516, dtype=torch.float64)
# training the nmf layer
# tensor(10.1890, dtype=torch.float64)
# training the classifier
# tensor(10.1635, dtype=torch.float64)
# tensor(10.1396, dtype=torch.float64)
# tensor(10.1256, dtype=torch.float64)
# tensor(10.1169, dtype=torch.float64)
# tensor(10.1113, dtype=torch.float64)
# tensor(10.1075, dtype=torch.float64)
# tensor(10.1046, dtype=torch.float64)
# tensor(10.1022, dtype=torch.float64)
# tensor(10.1002, dtype=torch.float64)
# tensor(10.0984, dtype=torch.float64)
# training the nmf layer
# tensor(9.9368, dtype=torch.float64)
# training the classifier
# tensor(9.9105, dtype=torch.float64)
# tensor(9.8877, dtype=torch.float64)
# tensor(9.8733, dtype=torch.float64)
# tensor(9.8639, dtype=torch.float64)
# tensor(9.8575, dtype=torch.float64)
# tensor(9.8530, dtype=torch.float64)
# tensor(9.8495, dtype=torch.float64)
# tensor(9.8468, dtype=torch.float64)
# tensor(9.8445, dtype=torch.float64)
# tensor(9.8425, dtype=torch.float64)
# training the nmf layer
# tensor(9.9004, dtype=torch.float64)
# training the classifier
# tensor(9.9448, dtype=torch.float64)
# tensor(9.8755, dtype=torch.float64)
# tensor(9.8383, dtype=torch.float64)
# tensor(9.8178, dtype=torch.float64)
# tensor(9.8061, dtype=torch.float64)
# tensor(9.7991, dtype=torch.float64)
# tensor(9.7946, dtype=torch.float64)
# tensor(9.7915, dtype=torch.float64)
# tensor(9.7892, dtype=torch.float64)
# tensor(9.7873, dtype=torch.float64)
# training the nmf layer
# tensor(9.8856, dtype=torch.float64)
# training the classifier
# tensor(9.9044, dtype=torch.float64)
# tensor(9.8286, dtype=torch.float64)
# tensor(9.7903, dtype=torch.float64)
# tensor(9.7699, dtype=torch.float64)
# tensor(9.7580, dtype=torch.float64)
# tensor(9.7504, dtype=torch.float64)
# tensor(9.7448, dtype=torch.float64)
# tensor(9.7404, dtype=torch.float64)
# tensor(9.7366, dtype=torch.float64)
# tensor(9.7333, dtype=torch.float64)
# training the nmf layer
# tensor(9.9218, dtype=torch.float64)
# training the classifier
# tensor(9.9906, dtype=torch.float64)
# tensor(9.8450, dtype=torch.float64)
# tensor(9.8068, dtype=torch.float64)
# tensor(9.7956, dtype=torch.float64)
# tensor(9.7911, dtype=torch.float64)
# tensor(9.7883, dtype=torch.float64)
# tensor(9.7862, dtype=torch.float64)
# tensor(9.7842, dtype=torch.float64)
# tensor(9.7824, dtype=torch.float64)
# tensor(9.7807, dtype=torch.float64)
# training the nmf layer
# tensor(10.1362, dtype=torch.float64)
# training the classifier
# tensor(10.1150, dtype=torch.float64)
# tensor(10.0144, dtype=torch.float64)
# tensor(9.9773, dtype=torch.float64)
# tensor(9.9590, dtype=torch.float64)
# tensor(9.9471, dtype=torch.float64)
# tensor(9.9377, dtype=torch.float64)
# tensor(9.9299, dtype=torch.float64)
# tensor(9.9232, dtype=torch.float64)
# tensor(9.9173, dtype=torch.float64)
# tensor(9.9122, dtype=torch.float64)
# training the nmf layer
# tensor(10.1407, dtype=torch.float64)
# training the classifier
# tensor(10.1270, dtype=torch.float64)
# tensor(10.0029, dtype=torch.float64)
# tensor(9.9770, dtype=torch.float64)
# tensor(9.9683, dtype=torch.float64)
# tensor(9.9628, dtype=torch.float64)
# tensor(9.9581, dtype=torch.float64)
# tensor(9.9539, dtype=torch.float64)
# tensor(9.9500, dtype=torch.float64)
# tensor(9.9464, dtype=torch.float64)
# tensor(9.9431, dtype=torch.float64)
# training the nmf layer
# tensor(9.6769, dtype=torch.float64)
# training the classifier
# tensor(9.6174, dtype=torch.float64)
# tensor(9.5243, dtype=torch.float64)
# tensor(9.5011, dtype=torch.float64)
# tensor(9.4938, dtype=torch.float64)
# tensor(9.4904, dtype=torch.float64)
# tensor(9.4880, dtype=torch.float64)
# tensor(9.4860, dtype=torch.float64)
# tensor(9.4841, dtype=torch.float64)
# tensor(9.4824, dtype=torch.float64)
# tensor(9.4808, dtype=torch.float64)
# training the nmf layer
# tensor(9.8447, dtype=torch.float64)
# training the classifier
# tensor(9.8141, dtype=torch.float64)
# ...
# training the nmf layer
# tensor(9.0492, dtype=torch.float64)
# training the classifier
# tensor(9.0492, dtype=torch.float64)
# tensor(9.0492, dtype=torch.float64)
# tensor(9.0492, dtype=torch.float64)
# tensor(9.0492, dtype=torch.float64)
# tensor(9.0492, dtype=torch.float64)
# tensor(9.0492, dtype=torch.float64)
# tensor(9.0492, dtype=torch.float64)
# tensor(9.0492, dtype=torch.float64)
# tensor(9.0492, dtype=torch.float64)
# tensor(9.0492, dtype=torch.float64)
# training the nmf layer
# tensor(9.4119, dtype=torch.float64)
# training the classifier
# tensor(9.4113, dtype=torch.float64)
# tensor(9.4113, dtype=torch.float64)
# tensor(9.4113, dtype=torch.float64)
# tensor(9.4113, dtype=torch.float64)
# tensor(9.4113, dtype=torch.float64)
# tensor(9.4112, dtype=torch.float64)
# tensor(9.4112, dtype=torch.float64)
# tensor(9.4112, dtype=torch.float64)
# tensor(9.4112, dtype=torch.float64)
# tensor(9.4112, dtype=torch.float64)
# training the nmf layer
# tensor(9.0783, dtype=torch.float64)
# training the classifier
# tensor(9.0783, dtype=torch.float64)
# tensor(9.0783, dtype=torch.float64)
# tensor(9.0783, dtype=torch.float64)
# tensor(9.0783, dtype=torch.float64)
# tensor(9.0783, dtype=torch.float64)
# tensor(9.0783, dtype=torch.float64)
# tensor(9.0783, dtype=torch.float64)
# tensor(9.0783, dtype=torch.float64)
# tensor(9.0783, dtype=torch.float64)
# tensor(9.0783, dtype=torch.float64)
# training the nmf layer
# tensor(9.0267, dtype=torch.float64)
# training the classifier
# tensor(9.0265, dtype=torch.float64)
# tensor(9.0265, dtype=torch.float64)
# tensor(9.0265, dtype=torch.float64)
# tensor(9.0265, dtype=torch.float64)
# tensor(9.0265, dtype=torch.float64)
# tensor(9.0265, dtype=torch.float64)
# tensor(9.0265, dtype=torch.float64)
# tensor(9.0265, dtype=torch.float64)
# tensor(9.0265, dtype=torch.float64)
# tensor(9.0265, dtype=torch.float64)
# training the nmf layer
# tensor(9.2483, dtype=torch.float64)
# training the classifier
# tensor(9.2483, dtype=torch.float64)
# tensor(9.2483, dtype=torch.float64)
# tensor(9.2483, dtype=torch.float64)
# tensor(9.2483, dtype=torch.float64)
# tensor(9.2483, dtype=torch.float64)
# tensor(9.2483, dtype=torch.float64)
# tensor(9.2483, dtype=torch.float64)
# tensor(9.2483, dtype=torch.float64)
# tensor(9.2483, dtype=torch.float64)
# tensor(9.2483, dtype=torch.float64)
# training the nmf layer
# tensor(9.3859, dtype=torch.float64)
# training the classifier
# tensor(9.3859, dtype=torch.float64)
# tensor(9.3859, dtype=torch.float64)
# tensor(9.3859, dtype=torch.float64)
# tensor(9.3859, dtype=torch.float64)
# tensor(9.3859, dtype=torch.float64)
# tensor(9.3859, dtype=torch.float64)
# tensor(9.3859, dtype=torch.float64)
# tensor(9.3859, dtype=torch.float64)
# tensor(9.3859, dtype=torch.float64)
# tensor(9.3859, dtype=torch.float64)
# training the nmf layer
# tensor(9.3806, dtype=torch.float64)
# training the classifier
# tensor(9.3804, dtype=torch.float64)
# tensor(9.3804, dtype=torch.float64)
# tensor(9.3804, dtype=torch.float64)
# tensor(9.3804, dtype=torch.float64)
# tensor(9.3804, dtype=torch.float64)
# tensor(9.3804, dtype=torch.float64)
# tensor(9.3804, dtype=torch.float64)
# tensor(9.3804, dtype=torch.float64)
# tensor(9.3804, dtype=torch.float64)
# tensor(9.3804, dtype=torch.float64)
# training the nmf layer
# tensor(9.0333, dtype=torch.float64)
# training the classifier
# tensor(9.0333, dtype=torch.float64)
# tensor(9.0333, dtype=torch.float64)
# tensor(9.0333, dtype=torch.float64)
# tensor(9.0333, dtype=torch.float64)
# tensor(9.0333, dtype=torch.float64)
# tensor(9.0333, dtype=torch.float64)
# tensor(9.0333, dtype=torch.float64)
# tensor(9.0333, dtype=torch.float64)
# tensor(9.0333, dtype=torch.float64)
# tensor(9.0333, dtype=torch.float64)
# training the nmf layer
# tensor(9.1410, dtype=torch.float64)
# training the classifier
# tensor(9.1410, dtype=torch.float64)
# tensor(9.1410, dtype=torch.float64)
# tensor(9.1410, dtype=torch.float64)
# tensor(9.1410, dtype=torch.float64)
# tensor(9.1410, dtype=torch.float64)
# tensor(9.1410, dtype=torch.float64)
# tensor(9.1410, dtype=torch.float64)
# tensor(9.1410, dtype=torch.float64)
# tensor(9.1410, dtype=torch.float64)
# tensor(9.1410, dtype=torch.float64)
# training the nmf layer
# tensor(9.4462, dtype=torch.float64)
# training the classifier
# tensor(9.4462, dtype=torch.float64)
# tensor(9.4462, dtype=torch.float64)
# tensor(9.4462, dtype=torch.float64)
# tensor(9.4462, dtype=torch.float64)
# tensor(9.4462, dtype=torch.float64)
# tensor(9.4462, dtype=torch.float64)
# tensor(9.4462, dtype=torch.float64)
# tensor(9.4462, dtype=torch.float64)
# tensor(9.4462, dtype=torch.float64)
# tensor(9.4462, dtype=torch.float64)
# training the nmf layer
# tensor(9.1798, dtype=torch.float64)
# training the classifier
# tensor(9.1798, dtype=torch.float64)
# tensor(9.1798, dtype=torch.float64)
# tensor(9.1798, dtype=torch.float64)
# tensor(9.1798, dtype=torch.float64)
# tensor(9.1798, dtype=torch.float64)
# tensor(9.1798, dtype=torch.float64)
# tensor(9.1798, dtype=torch.float64)
# tensor(9.1798, dtype=torch.float64)
# tensor(9.1798, dtype=torch.float64)
# tensor(9.1798, dtype=torch.float64)
# training the nmf layer
# tensor(8.7638, dtype=torch.float64)
# training the classifier
# tensor(8.7638, dtype=torch.float64)
# tensor(8.7638, dtype=torch.float64)
# tensor(8.7638, dtype=torch.float64)
# tensor(8.7638, dtype=torch.float64)
# tensor(8.7638, dtype=torch.float64)
# tensor(8.7638, dtype=torch.float64)
# tensor(8.7638, dtype=torch.float64)
# tensor(8.7638, dtype=torch.float64)
# tensor(8.7638, dtype=torch.float64)
# tensor(8.7638, dtype=torch.float64)
# training the nmf layer
# tensor(9.4605, dtype=torch.float64)
# training the classifier
# tensor(9.4605, dtype=torch.float64)
# tensor(9.4605, dtype=torch.float64)
# tensor(9.4605, dtype=torch.float64)
# tensor(9.4605, dtype=torch.float64)
# tensor(9.4605, dtype=torch.float64)
# tensor(9.4605, dtype=torch.float64)
# tensor(9.4605, dtype=torch.float64)
# tensor(9.4605, dtype=torch.float64)
# tensor(9.4605, dtype=torch.float64)
# tensor(9.4605, dtype=torch.float64)
# training the nmf layer
# tensor(9.1797, dtype=torch.float64)
# training the classifier
# tensor(9.1797, dtype=torch.float64)
# tensor(9.1797, dtype=torch.float64)
# tensor(9.1797, dtype=torch.float64)
# tensor(9.1797, dtype=torch.float64)
# tensor(9.1797, dtype=torch.float64)
# tensor(9.1797, dtype=torch.float64)
# tensor(9.1797, dtype=torch.float64)
# tensor(9.1797, dtype=torch.float64)
# tensor(9.1797, dtype=torch.float64)
# tensor(9.1797, dtype=torch.float64)
# training the nmf layer
# tensor(9.0254, dtype=torch.float64)
# training the classifier
# tensor(9.0254, dtype=torch.float64)
# tensor(9.0254, dtype=torch.float64)
# tensor(9.0254, dtype=torch.float64)
# tensor(9.0254, dtype=torch.float64)
# tensor(9.0254, dtype=torch.float64)
# tensor(9.0254, dtype=torch.float64)
# tensor(9.0254, dtype=torch.float64)
# tensor(9.0254, dtype=torch.float64)
# tensor(9.0254, dtype=torch.float64)
# tensor(9.0254, dtype=torch.float64)
# training the nmf layer
# tensor(9.1759, dtype=torch.float64)
# training the classifier
# tensor(9.1759, dtype=torch.float64)
# tensor(9.1759, dtype=torch.float64)
# tensor(9.1759, dtype=torch.float64)
# tensor(9.1759, dtype=torch.float64)
# tensor(9.1759, dtype=torch.float64)
# tensor(9.1759, dtype=torch.float64)
# tensor(9.1759, dtype=torch.float64)
# tensor(9.1759, dtype=torch.float64)
# tensor(9.1759, dtype=torch.float64)
# tensor(9.1759, dtype=torch.float64)
# training the nmf layer
# tensor(9.0392, dtype=torch.float64)
# training the classifier
# tensor(9.0392, dtype=torch.float64)
# tensor(9.0392, dtype=torch.float64)
# tensor(9.0392, dtype=torch.float64)
# tensor(9.0392, dtype=torch.float64)
# tensor(9.0392, dtype=torch.float64)
# tensor(9.0392, dtype=torch.float64)
# tensor(9.0392, dtype=torch.float64)
# tensor(9.0392, dtype=torch.float64)
# tensor(9.0392, dtype=torch.float64)
# tensor(9.0392, dtype=torch.float64)
# training the nmf layer
# tensor(9.2035, dtype=torch.float64)
# training the classifier
# tensor(9.2035, dtype=torch.float64)
# tensor(9.2035, dtype=torch.float64)
# tensor(9.2035, dtype=torch.float64)
# tensor(9.2035, dtype=torch.float64)
# tensor(9.2035, dtype=torch.float64)
# tensor(9.2035, dtype=torch.float64)
# tensor(9.2035, dtype=torch.float64)
# tensor(9.2035, dtype=torch.float64)
# tensor(9.2035, dtype=torch.float64)
# tensor(9.2035, dtype=torch.float64)
# training the nmf layer
# tensor(9.1818, dtype=torch.float64)
# training the classifier
# tensor(9.1818, dtype=torch.float64)
# tensor(9.1818, dtype=torch.float64)
# tensor(9.1818, dtype=torch.float64)
# tensor(9.1818, dtype=torch.float64)
# tensor(9.1818, dtype=torch.float64)
# tensor(9.1818, dtype=torch.float64)
# tensor(9.1818, dtype=torch.float64)
# tensor(9.1818, dtype=torch.float64)
# tensor(9.1818, dtype=torch.float64)
# tensor(9.1818, dtype=torch.float64)
# training the nmf layer
# tensor(9.1234, dtype=torch.float64)
# training the classifier
# tensor(9.1234, dtype=torch.float64)
# tensor(9.1234, dtype=torch.float64)
# tensor(9.1234, dtype=torch.float64)
# tensor(9.1234, dtype=torch.float64)
# tensor(9.1234, dtype=torch.float64)
# tensor(9.1234, dtype=torch.float64)
# tensor(9.1234, dtype=torch.float64)
# tensor(9.1234, dtype=torch.float64)
# tensor(9.1234, dtype=torch.float64)
# tensor(9.1234, dtype=torch.float64)
# training the nmf layer
# tensor(9.3761, dtype=torch.float64)
# training the classifier
# tensor(9.3761, dtype=torch.float64)
# tensor(9.3761, dtype=torch.float64)
# tensor(9.3761, dtype=torch.float64)
# tensor(9.3761, dtype=torch.float64)
# tensor(9.3761, dtype=torch.float64)
# tensor(9.3761, dtype=torch.float64)
# tensor(9.3761, dtype=torch.float64)
# tensor(9.3761, dtype=torch.float64)
# tensor(9.3761, dtype=torch.float64)
# tensor(9.3761, dtype=torch.float64)
# training the nmf layer
# tensor(8.8271, dtype=torch.float64)
# training the classifier
# tensor(8.8271, dtype=torch.float64)
# tensor(8.8271, dtype=torch.float64)
# tensor(8.8271, dtype=torch.float64)
# tensor(8.8271, dtype=torch.float64)
# tensor(8.8271, dtype=torch.float64)
# tensor(8.8271, dtype=torch.float64)
# tensor(8.8271, dtype=torch.float64)
# tensor(8.8271, dtype=torch.float64)
# tensor(8.8271, dtype=torch.float64)
# tensor(8.8271, dtype=torch.float64)
# training the nmf layer
# tensor(9.3290, dtype=torch.float64)
# training the classifier
# tensor(9.3290, dtype=torch.float64)
# tensor(9.3290, dtype=torch.float64)
# tensor(9.3290, dtype=torch.float64)
# tensor(9.3290, dtype=torch.float64)
# tensor(9.3290, dtype=torch.float64)
# tensor(9.3290, dtype=torch.float64)
# tensor(9.3290, dtype=torch.float64)
# tensor(9.3290, dtype=torch.float64)
# tensor(9.3290, dtype=torch.float64)
# tensor(9.3290, dtype=torch.float64)
# training the nmf layer
# tensor(9.5320, dtype=torch.float64)
# training the classifier
# tensor(9.5320, dtype=torch.float64)
# tensor(9.5320, dtype=torch.float64)
# tensor(9.5320, dtype=torch.float64)
# tensor(9.5320, dtype=torch.float64)
# tensor(9.5320, dtype=torch.float64)
# tensor(9.5320, dtype=torch.float64)
# tensor(9.5320, dtype=torch.float64)
# tensor(9.5320, dtype=torch.float64)
# tensor(9.5320, dtype=torch.float64)
# tensor(9.5320, dtype=torch.float64)
# training the nmf layer
# tensor(9.2794, dtype=torch.float64)
# training the classifier
# tensor(9.2794, dtype=torch.float64)
# tensor(9.2794, dtype=torch.float64)
# tensor(9.2794, dtype=torch.float64)
# tensor(9.2794, dtype=torch.float64)
# tensor(9.2794, dtype=torch.float64)
# tensor(9.2794, dtype=torch.float64)
# tensor(9.2794, dtype=torch.float64)
# tensor(9.2794, dtype=torch.float64)
# tensor(9.2794, dtype=torch.float64)
# tensor(9.2794, dtype=torch.float64)
# training the nmf layer
# tensor(9.3841, dtype=torch.float64)
# training the classifier
# tensor(9.3841, dtype=torch.float64)
# tensor(9.3841, dtype=torch.float64)
# tensor(9.3841, dtype=torch.float64)
# tensor(9.3841, dtype=torch.float64)
# tensor(9.3841, dtype=torch.float64)
# tensor(9.3841, dtype=torch.float64)
# tensor(9.3841, dtype=torch.float64)
# tensor(9.3841, dtype=torch.float64)
# tensor(9.3841, dtype=torch.float64)
# tensor(9.3841, dtype=torch.float64)
# training the nmf layer
# tensor(9.6087, dtype=torch.float64)
# training the classifier
# tensor(9.6087, dtype=torch.float64)
# tensor(9.6087, dtype=torch.float64)
# tensor(9.6087, dtype=torch.float64)
# tensor(9.6087, dtype=torch.float64)
# tensor(9.6087, dtype=torch.float64)
# tensor(9.6087, dtype=torch.float64)
# tensor(9.6087, dtype=torch.float64)
# tensor(9.6087, dtype=torch.float64)
# tensor(9.6087, dtype=torch.float64)
# tensor(9.6087, dtype=torch.float64)
# training the nmf layer
# tensor(9.0487, dtype=torch.float64)
# training the classifier
# tensor(9.0487, dtype=torch.float64)
# tensor(9.0487, dtype=torch.float64)
# tensor(9.0487, dtype=torch.float64)
# tensor(9.0487, dtype=torch.float64)
# tensor(9.0487, dtype=torch.float64)
# tensor(9.0487, dtype=torch.float64)
# tensor(9.0487, dtype=torch.float64)
# tensor(9.0487, dtype=torch.float64)
# tensor(9.0487, dtype=torch.float64)
# tensor(9.0487, dtype=torch.float64)
# training the nmf layer
# tensor(9.1403, dtype=torch.float64)
# training the classifier
# tensor(9.1402, dtype=torch.float64)
# tensor(9.1402, dtype=torch.float64)
# tensor(9.1402, dtype=torch.float64)
# tensor(9.1402, dtype=torch.float64)
# tensor(9.1402, dtype=torch.float64)
# tensor(9.1402, dtype=torch.float64)
# tensor(9.1402, dtype=torch.float64)
# tensor(9.1402, dtype=torch.float64)
# tensor(9.1402, dtype=torch.float64)
# tensor(9.1402, dtype=torch.float64)
# training the nmf layer
# tensor(9.4196, dtype=torch.float64)
# training the classifier
# tensor(9.4196, dtype=torch.float64)
# tensor(9.4196, dtype=torch.float64)
# tensor(9.4196, dtype=torch.float64)
# tensor(9.4196, dtype=torch.float64)
# tensor(9.4196, dtype=torch.float64)
# tensor(9.4196, dtype=torch.float64)
# tensor(9.4196, dtype=torch.float64)
# tensor(9.4196, dtype=torch.float64)
# tensor(9.4196, dtype=torch.float64)
# tensor(9.4196, dtype=torch.float64)
# training the nmf layer
# tensor(9.3629, dtype=torch.float64)
# training the classifier
# tensor(9.3629, dtype=torch.float64)
# tensor(9.3629, dtype=torch.float64)
# tensor(9.3629, dtype=torch.float64)
# tensor(9.3629, dtype=torch.float64)
# tensor(9.3629, dtype=torch.float64)
# tensor(9.3629, dtype=torch.float64)
# tensor(9.3629, dtype=torch.float64)
# tensor(9.3629, dtype=torch.float64)
# tensor(9.3629, dtype=torch.float64)
# tensor(9.3629, dtype=torch.float64)
# training the nmf layer
# tensor(8.8026, dtype=torch.float64)
# training the classifier
# tensor(8.8026, dtype=torch.float64)
# tensor(8.8026, dtype=torch.float64)
# tensor(8.8026, dtype=torch.float64)
# tensor(8.8026, dtype=torch.float64)
# tensor(8.8026, dtype=torch.float64)
# tensor(8.8026, dtype=torch.float64)
# tensor(8.8026, dtype=torch.float64)
# tensor(8.8026, dtype=torch.float64)
# tensor(8.8026, dtype=torch.float64)
# tensor(8.8026, dtype=torch.float64)
# training the nmf layer
# tensor(9.1691, dtype=torch.float64)
# training the classifier
# tensor(9.1691, dtype=torch.float64)
# tensor(9.1691, dtype=torch.float64)
# tensor(9.1691, dtype=torch.float64)
# tensor(9.1691, dtype=torch.float64)
# tensor(9.1691, dtype=torch.float64)
# tensor(9.1691, dtype=torch.float64)
# tensor(9.1691, dtype=torch.float64)
# tensor(9.1691, dtype=torch.float64)
# tensor(9.1691, dtype=torch.float64)
# tensor(9.1691, dtype=torch.float64)
# training the nmf layer
# tensor(8.9950, dtype=torch.float64)
# training the classifier
# tensor(8.9950, dtype=torch.float64)
# tensor(8.9950, dtype=torch.float64)
# tensor(8.9950, dtype=torch.float64)
# tensor(8.9950, dtype=torch.float64)
# tensor(8.9950, dtype=torch.float64)
# tensor(8.9950, dtype=torch.float64)
# tensor(8.9950, dtype=torch.float64)
# tensor(8.9950, dtype=torch.float64)
# tensor(8.9950, dtype=torch.float64)
# tensor(8.9950, dtype=torch.float64)
# training the nmf layer
# tensor(9.0205, dtype=torch.float64)
# training the classifier
# tensor(9.0205, dtype=torch.float64)
# tensor(9.0205, dtype=torch.float64)
# tensor(9.0205, dtype=torch.float64)
# tensor(9.0205, dtype=torch.float64)
# tensor(9.0205, dtype=torch.float64)
# tensor(9.0205, dtype=torch.float64)
# tensor(9.0205, dtype=torch.float64)
# tensor(9.0205, dtype=torch.float64)
# tensor(9.0205, dtype=torch.float64)
# tensor(9.0205, dtype=torch.float64)
# training the nmf layer
# tensor(8.6163, dtype=torch.float64)
# training the classifier
# tensor(8.6163, dtype=torch.float64)
# tensor(8.6163, dtype=torch.float64)
# tensor(8.6163, dtype=torch.float64)
# tensor(8.6163, dtype=torch.float64)
# tensor(8.6163, dtype=torch.float64)
# tensor(8.6163, dtype=torch.float64)
# tensor(8.6163, dtype=torch.float64)
# tensor(8.6163, dtype=torch.float64)
# tensor(8.6163, dtype=torch.float64)
# tensor(8.6163, dtype=torch.float64)
# epoch =  6
#  tensor(1734.8826, dtype=torch.float64)

# %%
plt.plot(loss_lst)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-04e5a826cfb7> in <module>()
# ----> 1 plt.plot(loss_lst)
#       2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
# SAVE YOUR RESULT!!!!!
A = net.lsqnonneglst[0].A.data
B = net.linear.weight.data
A_np = A.numpy()
B_np = B.numpy()
np.save('semi_50_A', A_np)
np.save('semi_50_B', B_np)

# %%
# Doing forward propagation on the whole dataset, remember to SAVE S and prod!
def get_whole_output(net, dataset, param_lst = None):
    history = Writer()
    # initialize the network with certain initial value
    if param_lst is not None:
        for (i,param) in enumerate(net.parameters()):
            param.data = param_lst[i]
    # start to forward propagate, 100 at a time
    n = len(dataset)
    if n%100 == 0:
        batch_num = n/100
    else:
        batch_num = n//100 + 1
    print('batch_num = ', batch_num, '\n')
    for i in range(batch_num):
        print('current at batch:', i)
        try:
            (inputs, label, l_batch) = dataset[i*100:(i+1)*100]
        except:
            (inputs, label, l_batch) = dataset[i*100:]
        history.add_tensor('label', label)
        output, pred = net(inputs)
        history.add_tensor('output', output)
        history.add_tensor('pred', pred)
    return history

# %%
history = get_whole_output(net, dataset)
# Out:
# batch_num =  189
#
# current at batch: 0
# current at batch: 1
# current at batch: 2
# current at batch: 3
# current at batch: 4
# current at batch: 5
# current at batch: 6
# current at batch: 7
# current at batch: 8
# current at batch: 9
# current at batch: 10
# current at batch: 11
# current at batch: 12
# current at batch: 13
# current at batch: 14
# current at batch: 15
# current at batch: 16
# current at batch: 17
# current at batch: 18
# current at batch: 19
# current at batch: 20
# current at batch: 21
# current at batch: 22
# current at batch: 23
# current at batch: 24
# current at batch: 25
# current at batch: 26
# current at batch: 27
# current at batch: 28
# current at batch: 29
# current at batch: 30
# current at batch: 31
# current at batch: 32
# current at batch: 33
# current at batch: 34
# current at batch: 35
# current at batch: 36
# current at batch: 37
# current at batch: 38
# current at batch: 39
# current at batch: 40
# current at batch: 41
# current at batch: 42
# current at batch: 43
# current at batch: 44
# current at batch: 45
# current at batch: 46
# current at batch: 47
# current at batch: 48
# current at batch: 49
# current at batch: 50
# current at batch: 51
# current at batch: 52
# current at batch: 53
# current at batch: 54
# current at batch: 55
# current at batch: 56
# current at batch: 57
# current at batch: 58
# current at batch: 59
# current at batch: 60
# current at batch: 61
# current at batch: 62
# current at batch: 63
# current at batch: 64
# current at batch: 65
# current at batch: 66
# current at batch: 67
# current at batch: 68
# current at batch: 69
# current at batch: 70
# current at batch: 71
# current at batch: 72
# current at batch: 73
# current at batch: 74
# current at batch: 75
# current at batch: 76
# current at batch: 77
# current at batch: 78
# current at batch: 79
# current at batch: 80
# current at batch: 81
# current at batch: 82
# current at batch: 83
# current at batch: 84
# current at batch: 85
# current at batch: 86
# current at batch: 87
# current at batch: 88
# current at batch: 89
# current at batch: 90
# current at batch: 91
# current at batch: 92
# current at batch: 93
# current at batch: 94
# current at batch: 95
# current at batch: 96
# current at batch: 97
# current at batch: 98
# current at batch: 99
# current at batch: 100
# current at batch: 101
# current at batch: 102
# current at batch: 103
# current at batch: 104
# current at batch: 105
# current at batch: 106
# current at batch: 107
# current at batch: 108
# current at batch: 109
# current at batch: 110
# current at batch: 111
# current at batch: 112
# current at batch: 113
# current at batch: 114
# current at batch: 115
# current at batch: 116
# current at batch: 117
# current at batch: 118
# current at batch: 119
# current at batch: 120
# current at batch: 121
# current at batch: 122
# current at batch: 123
# current at batch: 124
# current at batch: 125
# current at batch: 126
# current at batch: 127
# current at batch: 128
# current at batch: 129
# current at batch: 130
# current at batch: 131
# current at batch: 132
# current at batch: 133
# current at batch: 134
# current at batch: 135
# current at batch: 136
# current at batch: 137
# current at batch: 138
# current at batch: 139
# current at batch: 140
# current at batch: 141
# current at batch: 142
# current at batch: 143
# current at batch: 144
# current at batch: 145
# current at batch: 146
# current at batch: 147
# current at batch: 148
# current at batch: 149
# current at batch: 150
# current at batch: 151
# current at batch: 152
# current at batch: 153
# current at batch: 154
# current at batch: 155
# current at batch: 156
# current at batch: 157
# current at batch: 158
# current at batch: 159
# current at batch: 160
# current at batch: 161
# current at batch: 162
# current at batch: 163
# current at batch: 164
# current at batch: 165
# current at batch: 166
# current at batch: 167
# current at batch: 168
# current at batch: 169
# current at batch: 170
# current at batch: 171
# current at batch: 172
# current at batch: 173
# current at batch: 174
# current at batch: 175
# current at batch: 176
# current at batch: 177
# current at batch: 178
# current at batch: 179
# current at batch: 180
# current at batch: 181
# current at batch: 182
# current at batch: 183
# current at batch: 184
# current at batch: 185
# current at batch: 186
# current at batch: 187
# current at batch: 188
