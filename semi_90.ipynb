# %%
'''
Training a semi supervised one layer NMF on 20 news group dataset, with 90% of observing data
'''
# Out:
# '\nTraining a semi supervised one layer NMF on 20 news group dataset, with 90% of observing data\n'

# %%
# import package
import torch
from torch.autograd import Variable
import Ipynb_importer
from deep_nmf import Deep_NMF, Energy_Loss_Func
from writer import Writer
from matplotlib import pyplot as plt
import numpy as np
# Out:
# importing Jupyter notebook from deep_nmf.ipynb
# importing Jupyter notebook from lsqnonneg_module.ipynb
# importing Jupyter notebook from writer.ipynb

# %%
# load the dataset for twenty news
from twenty_news_group_data_loading import data, Y, L20, L50, L90, sparsedata_cr_entr, sparsedata_L2#, get_whole_output
# Out:
# importing Jupyter notebook from twenty_news_group_data_loading.ipynb

# %%
# Define the network
m = data.shape[1]
k = 20
c = 20
lambd = 100
net = Deep_NMF([m, k], c)
loss_func = Energy_Loss_Func(lambd = lambd, classification_type = 'L2')
dataset = sparsedata_L2(data*1000, Y, L90)

# %%
# Training process!

# setting training parameters
batchsize = 100
epoch = 7
lr_nmf = 5000
lr_cl = 0.1
loss_lst = []
total_loss_lst = []
# train!
for epo in range(epoch):
    dataloader = torch.utils.data.DataLoader(dataset, batch_size = batchsize, shuffle = True)
    total_loss = 0
    for (i, (inputs, label,l_batch)) in enumerate(dataloader):
        # train the lsqnonneg layers
        inputs = inputs.view([inputs.shape[0], inputs.shape[2]])
        label = label.view([label.shape[0], -1])
        l_batch = l_batch.view([l_batch.shape[0],-1])
        inputs, label = Variable(inputs), Variable(label)
        S_lst,pred = net(inputs)
        loss = loss_func(net, inputs, S_lst,pred,label,l_batch)
        loss.backward()
        loss_lst.append(loss.data)
        total_loss += loss.data
        print('training the nmf layer')
        print(loss.data)
        for A in net.lsqnonneglst.parameters():
            A.data = A.data.sub_(lr_nmf*A.grad.data)
            A.data = A.data.clamp(min = 0)
            A.requires_grad = False
        # train the linear classifier
        print('training the classifier')
        for k in range(10):
            net.zero_grad()
            S_lst,pred = net(inputs)
            loss = loss_func(net, inputs, S_lst,pred,label,l_batch)
            loss.backward()
            print(loss.data)
            for A in net.linear.parameters():
                A.data = A.data.sub_(lr_cl*A.grad.data)
        for A in net.lsqnonneglst.parameters():
            A.requires_grad = True
    print('epoch = ', epo, '\n', total_loss)
    total_loss_lst.append(total_loss)
# Out:
# training the nmf layer
# tensor(12.2394, dtype=torch.float64)
# training the classifier
# tensor(12.1661, dtype=torch.float64)
# tensor(12.1627, dtype=torch.float64)
# tensor(12.1593, dtype=torch.float64)
# tensor(12.1560, dtype=torch.float64)
# tensor(12.1527, dtype=torch.float64)
# tensor(12.1494, dtype=torch.float64)
# tensor(12.1463, dtype=torch.float64)
# tensor(12.1431, dtype=torch.float64)
# tensor(12.1400, dtype=torch.float64)
# tensor(12.1370, dtype=torch.float64)
# training the nmf layer
# tensor(12.1173, dtype=torch.float64)
# training the classifier
# tensor(12.0644, dtype=torch.float64)
# tensor(12.0588, dtype=torch.float64)
# tensor(12.0533, dtype=torch.float64)
# tensor(12.0480, dtype=torch.float64)
# tensor(12.0428, dtype=torch.float64)
# tensor(12.0378, dtype=torch.float64)
# tensor(12.0329, dtype=torch.float64)
# tensor(12.0282, dtype=torch.float64)
# tensor(12.0236, dtype=torch.float64)
# tensor(12.0191, dtype=torch.float64)
# training the nmf layer
# tensor(12.0331, dtype=torch.float64)
# training the classifier
# tensor(11.9763, dtype=torch.float64)
# tensor(11.9663, dtype=torch.float64)
# tensor(11.9573, dtype=torch.float64)
# tensor(11.9492, dtype=torch.float64)
# tensor(11.9420, dtype=torch.float64)
# tensor(11.9354, dtype=torch.float64)
# tensor(11.9296, dtype=torch.float64)
# tensor(11.9243, dtype=torch.float64)
# tensor(11.9196, dtype=torch.float64)
# tensor(11.9154, dtype=torch.float64)
# training the nmf layer
# tensor(11.7516, dtype=torch.float64)
# training the classifier
# tensor(11.7356, dtype=torch.float64)
# tensor(11.7195, dtype=torch.float64)
# tensor(11.7055, dtype=torch.float64)
# tensor(11.6932, dtype=torch.float64)
# tensor(11.6824, dtype=torch.float64)
# tensor(11.6730, dtype=torch.float64)
# tensor(11.6647, dtype=torch.float64)
# tensor(11.6575, dtype=torch.float64)
# tensor(11.6511, dtype=torch.float64)
# tensor(11.6456, dtype=torch.float64)
# training the nmf layer
# tensor(11.6816, dtype=torch.float64)
# training the classifier
# tensor(11.6484, dtype=torch.float64)
# tensor(11.6366, dtype=torch.float64)
# tensor(11.6268, dtype=torch.float64)
# tensor(11.6186, dtype=torch.float64)
# tensor(11.6118, dtype=torch.float64)
# tensor(11.6060, dtype=torch.float64)
# tensor(11.6012, dtype=torch.float64)
# tensor(11.5972, dtype=torch.float64)
# tensor(11.5939, dtype=torch.float64)
# tensor(11.5911, dtype=torch.float64)
# training the nmf layer
# tensor(11.8063, dtype=torch.float64)
# training the classifier
# tensor(11.7825, dtype=torch.float64)
# tensor(11.7675, dtype=torch.float64)
# tensor(11.7562, dtype=torch.float64)
# tensor(11.7478, dtype=torch.float64)
# tensor(11.7415, dtype=torch.float64)
# tensor(11.7368, dtype=torch.float64)
# tensor(11.7332, dtype=torch.float64)
# tensor(11.7306, dtype=torch.float64)
# tensor(11.7286, dtype=torch.float64)
# tensor(11.7271, dtype=torch.float64)
# training the nmf layer
# tensor(11.6769, dtype=torch.float64)
# training the classifier
# tensor(11.6547, dtype=torch.float64)
# tensor(11.6144, dtype=torch.float64)
# tensor(11.5866, dtype=torch.float64)
# tensor(11.5675, dtype=torch.float64)
# tensor(11.5543, dtype=torch.float64)
# tensor(11.5452, dtype=torch.float64)
# tensor(11.5389, dtype=torch.float64)
# tensor(11.5346, dtype=torch.float64)
# tensor(11.5316, dtype=torch.float64)
# tensor(11.5296, dtype=torch.float64)
# training the nmf layer
# tensor(11.9204, dtype=torch.float64)
# training the classifier
# tensor(11.8875, dtype=torch.float64)
# tensor(11.8223, dtype=torch.float64)
# tensor(11.7809, dtype=torch.float64)
# tensor(11.7546, dtype=torch.float64)
# tensor(11.7380, dtype=torch.float64)
# tensor(11.7274, dtype=torch.float64)
# tensor(11.7207, dtype=torch.float64)
# tensor(11.7164, dtype=torch.float64)
# tensor(11.7137, dtype=torch.float64)
# tensor(11.7120, dtype=torch.float64)
# training the nmf layer
# tensor(11.5028, dtype=torch.float64)
# training the classifier
# tensor(11.4555, dtype=torch.float64)
# tensor(11.4068, dtype=torch.float64)
# tensor(11.3798, dtype=torch.float64)
# tensor(11.3648, dtype=torch.float64)
# tensor(11.3566, dtype=torch.float64)
# tensor(11.3520, dtype=torch.float64)
# tensor(11.3494, dtype=torch.float64)
# tensor(11.3480, dtype=torch.float64)
# tensor(11.3472, dtype=torch.float64)
# tensor(11.3468, dtype=torch.float64)
# training the nmf layer
# tensor(11.8152, dtype=torch.float64)
# training the classifier
# tensor(11.7489, dtype=torch.float64)
# tensor(11.6873, dtype=torch.float64)
# tensor(11.6578, dtype=torch.float64)
# tensor(11.6437, dtype=torch.float64)
# tensor(11.6370, dtype=torch.float64)
# tensor(11.6337, dtype=torch.float64)
# tensor(11.6322, dtype=torch.float64)
# tensor(11.6314, dtype=torch.float64)
# tensor(11.6311, dtype=torch.float64)
# tensor(11.6309, dtype=torch.float64)
# training the nmf layer
# tensor(11.5677, dtype=torch.float64)
# training the classifier
# tensor(11.4574, dtype=torch.float64)
# tensor(11.3541, dtype=torch.float64)
# tensor(11.3266, dtype=torch.float64)
# tensor(11.3194, dtype=torch.float64)
# tensor(11.3174, dtype=torch.float64)
# tensor(11.3169, dtype=torch.float64)
# tensor(11.3168, dtype=torch.float64)
# tensor(11.3167, dtype=torch.float64)
# tensor(11.3167, dtype=torch.float64)
# tensor(11.3167, dtype=torch.float64)
# training the nmf layer
# tensor(11.8041, dtype=torch.float64)
# training the classifier
# tensor(11.6599, dtype=torch.float64)
# tensor(11.5845, dtype=torch.float64)
# tensor(11.5726, dtype=torch.float64)
# tensor(11.5707, dtype=torch.float64)
# tensor(11.5704, dtype=torch.float64)
# tensor(11.5703, dtype=torch.float64)
# tensor(11.5703, dtype=torch.float64)
# tensor(11.5703, dtype=torch.float64)
# tensor(11.5703, dtype=torch.float64)
# tensor(11.5703, dtype=torch.float64)
# training the nmf layer
# tensor(11.1217, dtype=torch.float64)
# training the classifier
# tensor(10.9510, dtype=torch.float64)
# tensor(10.9092, dtype=torch.float64)
# tensor(10.9043, dtype=torch.float64)
# tensor(10.9037, dtype=torch.float64)
# tensor(10.9037, dtype=torch.float64)
# tensor(10.9037, dtype=torch.float64)
# tensor(10.9037, dtype=torch.float64)
# tensor(10.9037, dtype=torch.float64)
# tensor(10.9037, dtype=torch.float64)
# tensor(10.9037, dtype=torch.float64)
# training the nmf layer
# tensor(11.0792, dtype=torch.float64)
# training the classifier
# tensor(10.8563, dtype=torch.float64)
# tensor(10.7919, dtype=torch.float64)
# tensor(10.7914, dtype=torch.float64)
# tensor(10.7914, dtype=torch.float64)
# tensor(10.7914, dtype=torch.float64)
# tensor(10.7914, dtype=torch.float64)
# tensor(10.7914, dtype=torch.float64)
# tensor(10.7914, dtype=torch.float64)
# tensor(10.7914, dtype=torch.float64)
# tensor(10.7914, dtype=torch.float64)
# training the nmf layer
# tensor(10.8307, dtype=torch.float64)
# training the classifier
# tensor(10.5862, dtype=torch.float64)
# tensor(10.4858, dtype=torch.float64)
# tensor(10.4856, dtype=torch.float64)
# tensor(10.4856, dtype=torch.float64)
# tensor(10.4856, dtype=torch.float64)
# tensor(10.4856, dtype=torch.float64)
# tensor(10.4856, dtype=torch.float64)
# tensor(10.4856, dtype=torch.float64)
# tensor(10.4856, dtype=torch.float64)
# tensor(10.4856, dtype=torch.float64)
# training the nmf layer
# tensor(10.6380, dtype=torch.float64)
# training the classifier
# tensor(10.3916, dtype=torch.float64)
# tensor(10.3028, dtype=torch.float64)
# tensor(10.2973, dtype=torch.float64)
# tensor(10.2970, dtype=torch.float64)
# tensor(10.2969, dtype=torch.float64)
# tensor(10.2969, dtype=torch.float64)
# tensor(10.2969, dtype=torch.float64)
# tensor(10.2969, dtype=torch.float64)
# tensor(10.2969, dtype=torch.float64)
# tensor(10.2969, dtype=torch.float64)
# training the nmf layer
# tensor(10.3884, dtype=torch.float64)
# training the classifier
# tensor(10.1498, dtype=torch.float64)
# tensor(10.0666, dtype=torch.float64)
# tensor(10.0497, dtype=torch.float64)
# tensor(10.0462, dtype=torch.float64)
# tensor(10.0455, dtype=torch.float64)
# tensor(10.0453, dtype=torch.float64)
# tensor(10.0453, dtype=torch.float64)
# tensor(10.0453, dtype=torch.float64)
# tensor(10.0453, dtype=torch.float64)
# tensor(10.0453, dtype=torch.float64)
# training the nmf layer
# tensor(9.9969, dtype=torch.float64)
# training the classifier
# tensor(9.7534, dtype=torch.float64)
# tensor(9.6908, dtype=torch.float64)
# tensor(9.6612, dtype=torch.float64)
# tensor(9.6472, dtype=torch.float64)
# tensor(9.6406, dtype=torch.float64)
# tensor(9.6374, dtype=torch.float64)
# tensor(9.6360, dtype=torch.float64)
# tensor(9.6353, dtype=torch.float64)
# tensor(9.6349, dtype=torch.float64)
# tensor(9.6348, dtype=torch.float64)
# training the nmf layer
# tensor(9.8858, dtype=torch.float64)
# training the classifier
# tensor(9.7020, dtype=torch.float64)
# tensor(9.6532, dtype=torch.float64)
# tensor(9.6295, dtype=torch.float64)
# tensor(9.6180, dtype=torch.float64)
# tensor(9.6124, dtype=torch.float64)
# tensor(9.6097, dtype=torch.float64)
# tensor(9.6084, dtype=torch.float64)
# tensor(9.6078, dtype=torch.float64)
# tensor(9.6075, dtype=torch.float64)
# tensor(9.6073, dtype=torch.float64)
# training the nmf layer
# tensor(9.6977, dtype=torch.float64)
# training the classifier
# tensor(9.5508, dtype=torch.float64)
# tensor(9.5138, dtype=torch.float64)
# tensor(9.4972, dtype=torch.float64)
# tensor(9.4897, dtype=torch.float64)
# tensor(9.4864, dtype=torch.float64)
# tensor(9.4849, dtype=torch.float64)
# tensor(9.4842, dtype=torch.float64)
# tensor(9.4839, dtype=torch.float64)
# tensor(9.4838, dtype=torch.float64)
# tensor(9.4837, dtype=torch.float64)
# training the nmf layer
# tensor(9.4704, dtype=torch.float64)
# training the classifier
# tensor(9.3621, dtype=torch.float64)
# tensor(9.3364, dtype=torch.float64)
# tensor(9.3247, dtype=torch.float64)
# tensor(9.3194, dtype=torch.float64)
# tensor(9.3169, dtype=torch.float64)
# tensor(9.3158, dtype=torch.float64)
# tensor(9.3153, dtype=torch.float64)
# tensor(9.3151, dtype=torch.float64)
# tensor(9.3150, dtype=torch.float64)
# tensor(9.3149, dtype=torch.float64)
# training the nmf layer
# tensor(9.9611, dtype=torch.float64)
# training the classifier
# tensor(9.8859, dtype=torch.float64)
# tensor(9.8433, dtype=torch.float64)
# tensor(9.8180, dtype=torch.float64)
# tensor(9.8030, dtype=torch.float64)
# tensor(9.7940, dtype=torch.float64)
# tensor(9.7887, dtype=torch.float64)
# tensor(9.7856, dtype=torch.float64)
# tensor(9.7837, dtype=torch.float64)
# tensor(9.7826, dtype=torch.float64)
# tensor(9.7820, dtype=torch.float64)
# training the nmf layer
# tensor(9.5798, dtype=torch.float64)
# training the classifier
# tensor(9.4973, dtype=torch.float64)
# tensor(9.5295, dtype=torch.float64)
# tensor(9.5742, dtype=torch.float64)
# tensor(9.6363, dtype=torch.float64)
# tensor(9.7223, dtype=torch.float64)
# tensor(9.8416, dtype=torch.float64)
# tensor(10.0072, dtype=torch.float64)
# tensor(10.2367, dtype=torch.float64)
# tensor(10.5551, dtype=torch.float64)
# tensor(10.9968, dtype=torch.float64)
# training the nmf layer
# tensor(10.6516, dtype=torch.float64)
# training the classifier
# tensor(10.3465, dtype=torch.float64)
# tensor(9.7091, dtype=torch.float64)
# tensor(9.3970, dtype=torch.float64)
# tensor(9.2442, dtype=torch.float64)
# tensor(9.1694, dtype=torch.float64)
# tensor(9.1328, dtype=torch.float64)
# tensor(9.1148, dtype=torch.float64)
# tensor(9.1061, dtype=torch.float64)
# tensor(9.1018, dtype=torch.float64)
# tensor(9.0997, dtype=torch.float64)
# training the nmf layer
# tensor(9.3496, dtype=torch.float64)
# training the classifier
# tensor(9.3088, dtype=torch.float64)
# tensor(9.2559, dtype=torch.float64)
# tensor(9.2362, dtype=torch.float64)
# tensor(9.2289, dtype=torch.float64)
# tensor(9.2262, dtype=torch.float64)
# tensor(9.2252, dtype=torch.float64)
# tensor(9.2248, dtype=torch.float64)
# tensor(9.2246, dtype=torch.float64)
# tensor(9.2246, dtype=torch.float64)
# tensor(9.2246, dtype=torch.float64)
# training the nmf layer
# tensor(8.9976, dtype=torch.float64)
# training the classifier
# tensor(8.9581, dtype=torch.float64)
# tensor(8.9036, dtype=torch.float64)
# tensor(8.8807, dtype=torch.float64)
# tensor(8.8711, dtype=torch.float64)
# tensor(8.8671, dtype=torch.float64)
# tensor(8.8654, dtype=torch.float64)
# tensor(8.8647, dtype=torch.float64)
# tensor(8.8644, dtype=torch.float64)
# tensor(8.8643, dtype=torch.float64)
# tensor(8.8642, dtype=torch.float64)
# training the nmf layer
# tensor(9.6002, dtype=torch.float64)
# training the classifier
# tensor(9.5687, dtype=torch.float64)
# tensor(9.5441, dtype=torch.float64)
# tensor(9.5275, dtype=torch.float64)
# tensor(9.5163, dtype=torch.float64)
# tensor(9.5087, dtype=torch.float64)
# tensor(9.5036, dtype=torch.float64)
# tensor(9.5001, dtype=torch.float64)
# tensor(9.4978, dtype=torch.float64)
# tensor(9.4962, dtype=torch.float64)
# tensor(9.4951, dtype=torch.float64)
# training the nmf layer
# tensor(9.2501, dtype=torch.float64)
# training the classifier
# tensor(9.2228, dtype=torch.float64)
# tensor(9.1754, dtype=torch.float64)
# tensor(9.1533, dtype=torch.float64)
# tensor(9.1429, dtype=torch.float64)
# tensor(9.1380, dtype=torch.float64)
# tensor(9.1358, dtype=torch.float64)
# tensor(9.1347, dtype=torch.float64)
# tensor(9.1342, dtype=torch.float64)
# tensor(9.1340, dtype=torch.float64)
# tensor(9.1339, dtype=torch.float64)
# training the nmf layer
# tensor(9.1768, dtype=torch.float64)
# training the classifier
# tensor(9.1569, dtype=torch.float64)
# tensor(9.1070, dtype=torch.float64)
# tensor(9.0941, dtype=torch.float64)
# tensor(9.0907, dtype=torch.float64)
# tensor(9.0899, dtype=torch.float64)
# tensor(9.0896, dtype=torch.float64)
# tensor(9.0896, dtype=torch.float64)
# tensor(9.0896, dtype=torch.float64)
# tensor(9.0896, dtype=torch.float64)
# tensor(9.0896, dtype=torch.float64)
# training the nmf layer
# tensor(9.5637, dtype=torch.float64)
# training the classifier
# tensor(9.5442, dtype=torch.float64)
# tensor(9.4645, dtype=torch.float64)
# tensor(9.4424, dtype=torch.float64)
# tensor(9.4363, dtype=torch.float64)
# tensor(9.4346, dtype=torch.float64)
# tensor(9.4342, dtype=torch.float64)
# tensor(9.4340, dtype=torch.float64)
# tensor(9.4340, dtype=torch.float64)
# tensor(9.4340, dtype=torch.float64)
# tensor(9.4340, dtype=torch.float64)
# training the nmf layer
# tensor(9.3150, dtype=torch.float64)
# training the classifier
# tensor(9.2976, dtype=torch.float64)
# tensor(9.2246, dtype=torch.float64)
# tensor(9.1889, dtype=torch.float64)
# tensor(9.1714, dtype=torch.float64)
# tensor(9.1628, dtype=torch.float64)
# tensor(9.1586, dtype=torch.float64)
# tensor(9.1566, dtype=torch.float64)
# tensor(9.1556, dtype=torch.float64)
# tensor(9.1551, dtype=torch.float64)
# tensor(9.1548, dtype=torch.float64)
# training the nmf layer
# tensor(9.3826, dtype=torch.float64)
# training the classifier
# tensor(9.3664, dtype=torch.float64)
# tensor(9.3232, dtype=torch.float64)
# tensor(9.3103, dtype=torch.float64)
# tensor(9.3065, dtype=torch.float64)
# tensor(9.3054, dtype=torch.float64)
# tensor(9.3050, dtype=torch.float64)
# tensor(9.3049, dtype=torch.float64)
# tensor(9.3049, dtype=torch.float64)
# tensor(9.3049, dtype=torch.float64)
# tensor(9.3049, dtype=torch.float64)
# training the nmf layer
# tensor(9.5064, dtype=torch.float64)
# training the classifier
# tensor(9.4917, dtype=torch.float64)
# tensor(9.4556, dtype=torch.float64)
# tensor(9.4451, dtype=torch.float64)
# tensor(9.4420, dtype=torch.float64)
# tensor(9.4411, dtype=torch.float64)
# tensor(9.4407, dtype=torch.float64)
# tensor(9.4406, dtype=torch.float64)
# tensor(9.4405, dtype=torch.float64)
# tensor(9.4404, dtype=torch.float64)
# tensor(9.4404, dtype=torch.float64)
# training the nmf layer
# tensor(9.1875, dtype=torch.float64)
# training the classifier
# tensor(9.1719, dtype=torch.float64)
# tensor(9.1313, dtype=torch.float64)
# tensor(9.1112, dtype=torch.float64)
# tensor(9.1012, dtype=torch.float64)
# tensor(9.0962, dtype=torch.float64)
# tensor(9.0938, dtype=torch.float64)
# tensor(9.0926, dtype=torch.float64)
# tensor(9.0920, dtype=torch.float64)
# tensor(9.0917, dtype=torch.float64)
# tensor(9.0915, dtype=torch.float64)
# training the nmf layer
# tensor(9.2625, dtype=torch.float64)
# training the classifier
# tensor(9.2474, dtype=torch.float64)
# tensor(9.1775, dtype=torch.float64)
# tensor(9.1556, dtype=torch.float64)
# tensor(9.1488, dtype=torch.float64)
# tensor(9.1466, dtype=torch.float64)
# tensor(9.1459, dtype=torch.float64)
# tensor(9.1456, dtype=torch.float64)
# tensor(9.1455, dtype=torch.float64)
# tensor(9.1454, dtype=torch.float64)
# tensor(9.1454, dtype=torch.float64)
# training the nmf layer
# tensor(9.3639, dtype=torch.float64)
# training the classifier
# tensor(9.3487, dtype=torch.float64)
# tensor(9.2751, dtype=torch.float64)
# tensor(9.2585, dtype=torch.float64)
# tensor(9.2547, dtype=torch.float64)
# tensor(9.2538, dtype=torch.float64)
# tensor(9.2536, dtype=torch.float64)
# tensor(9.2535, dtype=torch.float64)
# tensor(9.2535, dtype=torch.float64)
# tensor(9.2535, dtype=torch.float64)
# tensor(9.2535, dtype=torch.float64)
# training the nmf layer
# tensor(9.6012, dtype=torch.float64)
# training the classifier
# tensor(9.5841, dtype=torch.float64)
# tensor(9.4829, dtype=torch.float64)
# tensor(9.4452, dtype=torch.float64)
# tensor(9.4311, dtype=torch.float64)
# tensor(9.4258, dtype=torch.float64)
# tensor(9.4238, dtype=torch.float64)
# tensor(9.4230, dtype=torch.float64)
# tensor(9.4227, dtype=torch.float64)
# tensor(9.4225, dtype=torch.float64)
# tensor(9.4224, dtype=torch.float64)
# training the nmf layer
# tensor(9.5986, dtype=torch.float64)
# training the classifier
# tensor(9.5840, dtype=torch.float64)
# tensor(9.5317, dtype=torch.float64)
# tensor(9.5131, dtype=torch.float64)
# tensor(9.5064, dtype=torch.float64)
# tensor(9.5039, dtype=torch.float64)
# tensor(9.5030, dtype=torch.float64)
# tensor(9.5026, dtype=torch.float64)
# tensor(9.5025, dtype=torch.float64)
# tensor(9.5024, dtype=torch.float64)
# tensor(9.5023, dtype=torch.float64)
# training the nmf layer
# tensor(9.1286, dtype=torch.float64)
# training the classifier
# tensor(9.1059, dtype=torch.float64)
# tensor(9.0428, dtype=torch.float64)
# tensor(9.0167, dtype=torch.float64)
# tensor(9.0058, dtype=torch.float64)
# tensor(9.0011, dtype=torch.float64)
# tensor(8.9990, dtype=torch.float64)
# tensor(8.9978, dtype=torch.float64)
# tensor(8.9971, dtype=torch.float64)
# tensor(8.9966, dtype=torch.float64)
# tensor(8.9961, dtype=torch.float64)
# training the nmf layer
# tensor(9.6739, dtype=torch.float64)
# training the classifier
# tensor(9.6540, dtype=torch.float64)
# tensor(9.5874, dtype=torch.float64)
# tensor(9.5750, dtype=torch.float64)
# tensor(9.5726, dtype=torch.float64)
# tensor(9.5720, dtype=torch.float64)
# tensor(9.5717, dtype=torch.float64)
# tensor(9.5714, dtype=torch.float64)
# tensor(9.5712, dtype=torch.float64)
# tensor(9.5709, dtype=torch.float64)
# tensor(9.5707, dtype=torch.float64)
# training the nmf layer
# tensor(9.2041, dtype=torch.float64)
# training the classifier
# tensor(9.1818, dtype=torch.float64)
# tensor(9.1371, dtype=torch.float64)
# tensor(9.1168, dtype=torch.float64)
# tensor(9.1074, dtype=torch.float64)
# tensor(9.1031, dtype=torch.float64)
# tensor(9.1010, dtype=torch.float64)
# tensor(9.0999, dtype=torch.float64)
# tensor(9.0993, dtype=torch.float64)
# tensor(9.0989, dtype=torch.float64)
# tensor(9.0987, dtype=torch.float64)
# training the nmf layer
# tensor(8.8329, dtype=torch.float64)
# training the classifier
# tensor(8.8125, dtype=torch.float64)
# tensor(8.7285, dtype=torch.float64)
# tensor(8.6966, dtype=torch.float64)
# tensor(8.6846, dtype=torch.float64)
# tensor(8.6799, dtype=torch.float64)
# tensor(8.6781, dtype=torch.float64)
# tensor(8.6774, dtype=torch.float64)
# tensor(8.6771, dtype=torch.float64)
# tensor(8.6769, dtype=torch.float64)
# tensor(8.6768, dtype=torch.float64)
# training the nmf layer
# tensor(9.1978, dtype=torch.float64)
# training the classifier
# tensor(9.1789, dtype=torch.float64)
# tensor(9.0837, dtype=torch.float64)
# tensor(9.0512, dtype=torch.float64)
# tensor(9.0401, dtype=torch.float64)
# tensor(9.0363, dtype=torch.float64)
# tensor(9.0350, dtype=torch.float64)
# tensor(9.0345, dtype=torch.float64)
# tensor(9.0343, dtype=torch.float64)
# tensor(9.0342, dtype=torch.float64)
# tensor(9.0342, dtype=torch.float64)
# training the nmf layer
# tensor(9.2443, dtype=torch.float64)
# training the classifier
# tensor(9.2168, dtype=torch.float64)
# tensor(9.1338, dtype=torch.float64)
# tensor(9.1244, dtype=torch.float64)
# tensor(9.1232, dtype=torch.float64)
# tensor(9.1230, dtype=torch.float64)
# tensor(9.1228, dtype=torch.float64)
# tensor(9.1226, dtype=torch.float64)
# tensor(9.1225, dtype=torch.float64)
# tensor(9.1223, dtype=torch.float64)
# tensor(9.1221, dtype=torch.float64)
# training the nmf layer
# tensor(9.7025, dtype=torch.float64)
# training the classifier
# tensor(9.6798, dtype=torch.float64)
# tensor(9.6036, dtype=torch.float64)
# tensor(9.5954, dtype=torch.float64)
# tensor(9.5944, dtype=torch.float64)
# tensor(9.5941, dtype=torch.float64)
# tensor(9.5939, dtype=torch.float64)
# tensor(9.5938, dtype=torch.float64)
# tensor(9.5936, dtype=torch.float64)
# tensor(9.5934, dtype=torch.float64)
# tensor(9.5933, dtype=torch.float64)
# training the nmf layer
# tensor(9.4144, dtype=torch.float64)
# training the classifier
# tensor(9.3853, dtype=torch.float64)
# tensor(9.3259, dtype=torch.float64)
# tensor(9.3022, dtype=torch.float64)
# tensor(9.2927, dtype=torch.float64)
# tensor(9.2888, dtype=torch.float64)
# tensor(9.2870, dtype=torch.float64)
# tensor(9.2862, dtype=torch.float64)
# tensor(9.2856, dtype=torch.float64)
# tensor(9.2853, dtype=torch.float64)
# tensor(9.2849, dtype=torch.float64)
# training the nmf layer
# tensor(9.4243, dtype=torch.float64)
# training the classifier
# tensor(9.3936, dtype=torch.float64)
# tensor(9.3073, dtype=torch.float64)
# tensor(9.2967, dtype=torch.float64)
# tensor(9.2952, dtype=torch.float64)
# tensor(9.2949, dtype=torch.float64)
# tensor(9.2947, dtype=torch.float64)
# tensor(9.2945, dtype=torch.float64)
# tensor(9.2943, dtype=torch.float64)
# tensor(9.2941, dtype=torch.float64)
# tensor(9.2939, dtype=torch.float64)
# training the nmf layer
# tensor(9.3833, dtype=torch.float64)
# training the classifier
# tensor(9.3589, dtype=torch.float64)
# tensor(9.2338, dtype=torch.float64)
# tensor(9.2214, dtype=torch.float64)
# tensor(9.2200, dtype=torch.float64)
# tensor(9.2197, dtype=torch.float64)
# tensor(9.2195, dtype=torch.float64)
# tensor(9.2193, dtype=torch.float64)
# tensor(9.2191, dtype=torch.float64)
# tensor(9.2189, dtype=torch.float64)
# tensor(9.2187, dtype=torch.float64)
# training the nmf layer
# tensor(9.0230, dtype=torch.float64)
# training the classifier
# tensor(8.9937, dtype=torch.float64)
# tensor(8.9105, dtype=torch.float64)
# tensor(8.8901, dtype=torch.float64)
# tensor(8.8849, dtype=torch.float64)
# tensor(8.8835, dtype=torch.float64)
# tensor(8.8830, dtype=torch.float64)
# tensor(8.8827, dtype=torch.float64)
# tensor(8.8825, dtype=torch.float64)
# tensor(8.8823, dtype=torch.float64)
# tensor(8.8821, dtype=torch.float64)
# training the nmf layer
# tensor(9.1402, dtype=torch.float64)
# training the classifier
# tensor(9.1081, dtype=torch.float64)
# tensor(9.0407, dtype=torch.float64)
# tensor(9.0127, dtype=torch.float64)
# tensor(9.0009, dtype=torch.float64)
# tensor(8.9959, dtype=torch.float64)
# tensor(8.9937, dtype=torch.float64)
# tensor(8.9926, dtype=torch.float64)
# tensor(8.9920, dtype=torch.float64)
# tensor(8.9916, dtype=torch.float64)
# tensor(8.9913, dtype=torch.float64)
# training the nmf layer
# tensor(9.2626, dtype=torch.float64)
# training the classifier
# tensor(9.2294, dtype=torch.float64)
# tensor(9.0932, dtype=torch.float64)
# tensor(9.0750, dtype=torch.float64)
# tensor(9.0725, dtype=torch.float64)
# tensor(9.0721, dtype=torch.float64)
# tensor(9.0719, dtype=torch.float64)
# tensor(9.0717, dtype=torch.float64)
# tensor(9.0716, dtype=torch.float64)
# tensor(9.0714, dtype=torch.float64)
# tensor(9.0713, dtype=torch.float64)
# training the nmf layer
# tensor(9.4883, dtype=torch.float64)
# training the classifier
# tensor(9.4589, dtype=torch.float64)
# tensor(9.3637, dtype=torch.float64)
# tensor(9.3422, dtype=torch.float64)
# tensor(9.3370, dtype=torch.float64)
# tensor(9.3356, dtype=torch.float64)
# tensor(9.3349, dtype=torch.float64)
# tensor(9.3345, dtype=torch.float64)
# tensor(9.3340, dtype=torch.float64)
# tensor(9.3336, dtype=torch.float64)
# tensor(9.3332, dtype=torch.float64)
# training the nmf layer
# tensor(8.9861, dtype=torch.float64)
# training the classifier
# tensor(8.9556, dtype=torch.float64)
# tensor(8.8421, dtype=torch.float64)
# tensor(8.8200, dtype=torch.float64)
# tensor(8.8155, dtype=torch.float64)
# tensor(8.8146, dtype=torch.float64)
# tensor(8.8142, dtype=torch.float64)
# tensor(8.8140, dtype=torch.float64)
# tensor(8.8139, dtype=torch.float64)
# tensor(8.8137, dtype=torch.float64)
# tensor(8.8136, dtype=torch.float64)
# training the nmf layer
# tensor(9.3777, dtype=torch.float64)
# training the classifier
# tensor(9.3461, dtype=torch.float64)
# tensor(9.2849, dtype=torch.float64)
# tensor(9.2753, dtype=torch.float64)
# tensor(9.2735, dtype=torch.float64)
# tensor(9.2729, dtype=torch.float64)
# tensor(9.2725, dtype=torch.float64)
# tensor(9.2721, dtype=torch.float64)
# tensor(9.2717, dtype=torch.float64)
# tensor(9.2713, dtype=torch.float64)
# tensor(9.2710, dtype=torch.float64)
# training the nmf layer
# tensor(9.1091, dtype=torch.float64)
# training the classifier
# tensor(9.0697, dtype=torch.float64)
# tensor(8.9969, dtype=torch.float64)
# tensor(8.9882, dtype=torch.float64)
# tensor(8.9867, dtype=torch.float64)
# tensor(8.9859, dtype=torch.float64)
# tensor(8.9853, dtype=torch.float64)
# tensor(8.9847, dtype=torch.float64)
# tensor(8.9841, dtype=torch.float64)
# tensor(8.9835, dtype=torch.float64)
# tensor(8.9829, dtype=torch.float64)
# training the nmf layer
# tensor(9.3177, dtype=torch.float64)
# training the classifier
# tensor(9.2819, dtype=torch.float64)
# tensor(9.1710, dtype=torch.float64)
# tensor(9.1594, dtype=torch.float64)
# tensor(9.1579, dtype=torch.float64)
# tensor(9.1574, dtype=torch.float64)
# tensor(9.1570, dtype=torch.float64)
# tensor(9.1566, dtype=torch.float64)
# tensor(9.1562, dtype=torch.float64)
# tensor(9.1558, dtype=torch.float64)
# tensor(9.1554, dtype=torch.float64)
# training the nmf layer
# tensor(9.4678, dtype=torch.float64)
# training the classifier
# tensor(9.4313, dtype=torch.float64)
# tensor(9.2998, dtype=torch.float64)
# tensor(9.2739, dtype=torch.float64)
# tensor(9.2685, dtype=torch.float64)
# tensor(9.2671, dtype=torch.float64)
# tensor(9.2664, dtype=torch.float64)
# tensor(9.2659, dtype=torch.float64)
# tensor(9.2655, dtype=torch.float64)
# tensor(9.2650, dtype=torch.float64)
# tensor(9.2646, dtype=torch.float64)
# training the nmf layer
# tensor(9.4263, dtype=torch.float64)
# training the classifier
# tensor(9.3932, dtype=torch.float64)
# tensor(9.3144, dtype=torch.float64)
# tensor(9.3073, dtype=torch.float64)
# tensor(9.3062, dtype=torch.float64)
# tensor(9.3057, dtype=torch.float64)
# tensor(9.3053, dtype=torch.float64)
# tensor(9.3048, dtype=torch.float64)
# tensor(9.3044, dtype=torch.float64)
# tensor(9.3039, dtype=torch.float64)
# tensor(9.3035, dtype=torch.float64)
# training the nmf layer
# tensor(9.1626, dtype=torch.float64)
# training the classifier
# tensor(9.1308, dtype=torch.float64)
# tensor(9.0367, dtype=torch.float64)
# tensor(9.0258, dtype=torch.float64)
# tensor(9.0243, dtype=torch.float64)
# tensor(9.0239, dtype=torch.float64)
# tensor(9.0237, dtype=torch.float64)
# tensor(9.0234, dtype=torch.float64)
# tensor(9.0232, dtype=torch.float64)
# tensor(9.0229, dtype=torch.float64)
# tensor(9.0227, dtype=torch.float64)
# training the nmf layer
# tensor(9.2495, dtype=torch.float64)
# training the classifier
# tensor(9.2150, dtype=torch.float64)
# tensor(9.0720, dtype=torch.float64)
# tensor(9.0504, dtype=torch.float64)
# tensor(9.0468, dtype=torch.float64)
# tensor(9.0458, dtype=torch.float64)
# tensor(9.0453, dtype=torch.float64)
# tensor(9.0448, dtype=torch.float64)
# tensor(9.0443, dtype=torch.float64)
# tensor(9.0438, dtype=torch.float64)
# tensor(9.0433, dtype=torch.float64)
# training the nmf layer
# tensor(8.9616, dtype=torch.float64)
# training the classifier
# tensor(8.9240, dtype=torch.float64)
# tensor(8.8583, dtype=torch.float64)
# tensor(8.8467, dtype=torch.float64)
# tensor(8.8445, dtype=torch.float64)
# tensor(8.8438, dtype=torch.float64)
# tensor(8.8434, dtype=torch.float64)
# tensor(8.8430, dtype=torch.float64)
# tensor(8.8426, dtype=torch.float64)
# tensor(8.8423, dtype=torch.float64)
# tensor(8.8419, dtype=torch.float64)
# training the nmf layer
# tensor(9.0446, dtype=torch.float64)
# training the classifier
# tensor(9.0124, dtype=torch.float64)
# tensor(8.9229, dtype=torch.float64)
# tensor(8.9041, dtype=torch.float64)
# tensor(8.8999, dtype=torch.float64)
# tensor(8.8988, dtype=torch.float64)
# tensor(8.8983, dtype=torch.float64)
# tensor(8.8979, dtype=torch.float64)
# tensor(8.8976, dtype=torch.float64)
# tensor(8.8973, dtype=torch.float64)
# tensor(8.8970, dtype=torch.float64)
# training the nmf layer
# tensor(9.3629, dtype=torch.float64)
# training the classifier
# tensor(9.3211, dtype=torch.float64)
# tensor(9.2321, dtype=torch.float64)
# tensor(9.2214, dtype=torch.float64)
# tensor(9.2198, dtype=torch.float64)
# tensor(9.2193, dtype=torch.float64)
# tensor(9.2189, dtype=torch.float64)
# tensor(9.2186, dtype=torch.float64)
# tensor(9.2182, dtype=torch.float64)
# tensor(9.2179, dtype=torch.float64)
# tensor(9.2175, dtype=torch.float64)
# training the nmf layer
# tensor(9.0682, dtype=torch.float64)
# training the classifier
# tensor(9.0352, dtype=torch.float64)
# tensor(8.9919, dtype=torch.float64)
# tensor(8.9869, dtype=torch.float64)
# tensor(8.9861, dtype=torch.float64)
# tensor(8.9857, dtype=torch.float64)
# tensor(8.9853, dtype=torch.float64)
# tensor(8.9849, dtype=torch.float64)
# tensor(8.9845, dtype=torch.float64)
# tensor(8.9842, dtype=torch.float64)
# tensor(8.9838, dtype=torch.float64)
# training the nmf layer
# tensor(9.1793, dtype=torch.float64)
# training the classifier
# tensor(9.1317, dtype=torch.float64)
# tensor(9.0786, dtype=torch.float64)
# tensor(9.0703, dtype=torch.float64)
# tensor(9.0685, dtype=torch.float64)
# tensor(9.0677, dtype=torch.float64)
# tensor(9.0670, dtype=torch.float64)
# tensor(9.0663, dtype=torch.float64)
# tensor(9.0656, dtype=torch.float64)
# tensor(9.0649, dtype=torch.float64)
# tensor(9.0643, dtype=torch.float64)
# training the nmf layer
# tensor(9.1777, dtype=torch.float64)
# training the classifier
# tensor(9.1358, dtype=torch.float64)
# tensor(9.0535, dtype=torch.float64)
# tensor(9.0397, dtype=torch.float64)
# tensor(9.0368, dtype=torch.float64)
# tensor(9.0355, dtype=torch.float64)
# tensor(9.0346, dtype=torch.float64)
# tensor(9.0337, dtype=torch.float64)
# tensor(9.0328, dtype=torch.float64)
# tensor(9.0319, dtype=torch.float64)
# tensor(9.0310, dtype=torch.float64)
# training the nmf layer
# tensor(8.9028, dtype=torch.float64)
# training the classifier
# tensor(8.8603, dtype=torch.float64)
# tensor(8.7490, dtype=torch.float64)
# tensor(8.7449, dtype=torch.float64)
# tensor(8.7441, dtype=torch.float64)
# tensor(8.7434, dtype=torch.float64)
# tensor(8.7427, dtype=torch.float64)
# tensor(8.7420, dtype=torch.float64)
# tensor(8.7413, dtype=torch.float64)
# tensor(8.7406, dtype=torch.float64)
# tensor(8.7399, dtype=torch.float64)
# training the nmf layer
# tensor(9.5276, dtype=torch.float64)
# training the classifier
# tensor(9.4888, dtype=torch.float64)
# tensor(9.3663, dtype=torch.float64)
# tensor(9.3459, dtype=torch.float64)
# tensor(9.3419, dtype=torch.float64)
# tensor(9.3405, dtype=torch.float64)
# tensor(9.3396, dtype=torch.float64)
# tensor(9.3387, dtype=torch.float64)
# tensor(9.3379, dtype=torch.float64)
# tensor(9.3370, dtype=torch.float64)
# tensor(9.3362, dtype=torch.float64)
# training the nmf layer
# tensor(9.0597, dtype=torch.float64)
# training the classifier
# tensor(9.0192, dtype=torch.float64)
# tensor(8.9328, dtype=torch.float64)
# tensor(8.9128, dtype=torch.float64)
# tensor(8.9078, dtype=torch.float64)
# tensor(8.9063, dtype=torch.float64)
# tensor(8.9056, dtype=torch.float64)
# tensor(8.9050, dtype=torch.float64)
# tensor(8.9045, dtype=torch.float64)
# tensor(8.9040, dtype=torch.float64)
# tensor(8.9036, dtype=torch.float64)
# training the nmf layer
# tensor(9.4807, dtype=torch.float64)
# training the classifier
# tensor(9.4153, dtype=torch.float64)
# tensor(9.3106, dtype=torch.float64)
# tensor(9.3038, dtype=torch.float64)
# tensor(9.3028, dtype=torch.float64)
# tensor(9.3022, dtype=torch.float64)
# tensor(9.3016, dtype=torch.float64)
# tensor(9.3010, dtype=torch.float64)
# tensor(9.3004, dtype=torch.float64)
# tensor(9.2999, dtype=torch.float64)
# tensor(9.2993, dtype=torch.float64)
# training the nmf layer
# tensor(9.1485, dtype=torch.float64)
# training the classifier
# tensor(9.1045, dtype=torch.float64)
# tensor(9.0373, dtype=torch.float64)
# tensor(9.0289, dtype=torch.float64)
# tensor(9.0274, dtype=torch.float64)
# tensor(9.0267, dtype=torch.float64)
# tensor(9.0261, dtype=torch.float64)
# tensor(9.0255, dtype=torch.float64)
# tensor(9.0250, dtype=torch.float64)
# tensor(9.0244, dtype=torch.float64)
# tensor(9.0238, dtype=torch.float64)
# training the nmf layer
# tensor(9.1484, dtype=torch.float64)
# training the classifier
# tensor(9.0963, dtype=torch.float64)
# tensor(8.9822, dtype=torch.float64)
# tensor(8.9708, dtype=torch.float64)
# tensor(8.9689, dtype=torch.float64)
# tensor(8.9679, dtype=torch.float64)
# tensor(8.9670, dtype=torch.float64)
# tensor(8.9661, dtype=torch.float64)
# tensor(8.9652, dtype=torch.float64)
# tensor(8.9643, dtype=torch.float64)
# tensor(8.9635, dtype=torch.float64)
# training the nmf layer
# tensor(8.7615, dtype=torch.float64)
# training the classifier
# tensor(8.7106, dtype=torch.float64)
# tensor(8.6274, dtype=torch.float64)
# tensor(8.6156, dtype=torch.float64)
# tensor(8.6135, dtype=torch.float64)
# tensor(8.6127, dtype=torch.float64)
# tensor(8.6121, dtype=torch.float64)
# tensor(8.6116, dtype=torch.float64)
# tensor(8.6110, dtype=torch.float64)
# tensor(8.6105, dtype=torch.float64)
# tensor(8.6099, dtype=torch.float64)
# training the nmf layer
# tensor(9.5354, dtype=torch.float64)
# training the classifier
# tensor(9.4748, dtype=torch.float64)
# tensor(9.4017, dtype=torch.float64)
# tensor(9.3968, dtype=torch.float64)
# tensor(9.3959, dtype=torch.float64)
# tensor(9.3952, dtype=torch.float64)
# tensor(9.3946, dtype=torch.float64)
# tensor(9.3939, dtype=torch.float64)
# tensor(9.3932, dtype=torch.float64)
# tensor(9.3926, dtype=torch.float64)
# tensor(9.3919, dtype=torch.float64)
# training the nmf layer
# tensor(8.8730, dtype=torch.float64)
# training the classifier
# tensor(8.8258, dtype=torch.float64)
# tensor(8.7245, dtype=torch.float64)
# tensor(8.7054, dtype=torch.float64)
# tensor(8.7014, dtype=torch.float64)
# tensor(8.7000, dtype=torch.float64)
# tensor(8.6992, dtype=torch.float64)
# tensor(8.6985, dtype=torch.float64)
# tensor(8.6978, dtype=torch.float64)
# tensor(8.6972, dtype=torch.float64)
# tensor(8.6965, dtype=torch.float64)
# training the nmf layer
# tensor(9.4018, dtype=torch.float64)
# training the classifier
# tensor(9.3153, dtype=torch.float64)
# tensor(9.1718, dtype=torch.float64)
# tensor(9.1633, dtype=torch.float64)
# tensor(9.1622, dtype=torch.float64)
# tensor(9.1615, dtype=torch.float64)
# tensor(9.1608, dtype=torch.float64)
# tensor(9.1602, dtype=torch.float64)
# tensor(9.1595, dtype=torch.float64)
# tensor(9.1588, dtype=torch.float64)
# tensor(9.1582, dtype=torch.float64)
# training the nmf layer
# tensor(9.1642, dtype=torch.float64)
# training the classifier
# tensor(9.0932, dtype=torch.float64)
# tensor(9.0342, dtype=torch.float64)
# tensor(9.0317, dtype=torch.float64)
# tensor(9.0307, dtype=torch.float64)
# tensor(9.0298, dtype=torch.float64)
# tensor(9.0290, dtype=torch.float64)
# tensor(9.0281, dtype=torch.float64)
# tensor(9.0272, dtype=torch.float64)
# tensor(9.0263, dtype=torch.float64)
# tensor(9.0255, dtype=torch.float64)
# training the nmf layer
# tensor(9.3322, dtype=torch.float64)
# training the classifier
# tensor(9.2710, dtype=torch.float64)
# tensor(9.2109, dtype=torch.float64)
# tensor(9.2078, dtype=torch.float64)
# tensor(9.2069, dtype=torch.float64)
# tensor(9.2061, dtype=torch.float64)
# tensor(9.2053, dtype=torch.float64)
# tensor(9.2045, dtype=torch.float64)
# tensor(9.2037, dtype=torch.float64)
# tensor(9.2029, dtype=torch.float64)
# tensor(9.2021, dtype=torch.float64)
# training the nmf layer
# tensor(9.0419, dtype=torch.float64)
# training the classifier
# tensor(8.9748, dtype=torch.float64)
# tensor(8.9016, dtype=torch.float64)
# tensor(8.8958, dtype=torch.float64)
# tensor(8.8949, dtype=torch.float64)
# tensor(8.8943, dtype=torch.float64)
# tensor(8.8937, dtype=torch.float64)
# tensor(8.8932, dtype=torch.float64)
# tensor(8.8926, dtype=torch.float64)
# tensor(8.8921, dtype=torch.float64)
# tensor(8.8915, dtype=torch.float64)
# training the nmf layer
# tensor(9.3892, dtype=torch.float64)
# training the classifier
# tensor(9.3061, dtype=torch.float64)
# tensor(9.2612, dtype=torch.float64)
# tensor(9.2596, dtype=torch.float64)
# tensor(9.2586, dtype=torch.float64)
# tensor(9.2576, dtype=torch.float64)
# tensor(9.2566, dtype=torch.float64)
# tensor(9.2557, dtype=torch.float64)
# tensor(9.2547, dtype=torch.float64)
# tensor(9.2538, dtype=torch.float64)
# tensor(9.2528, dtype=torch.float64)
# training the nmf layer
# tensor(8.8503, dtype=torch.float64)
# training the classifier
# tensor(8.7847, dtype=torch.float64)
# tensor(8.7145, dtype=torch.float64)
# tensor(8.7066, dtype=torch.float64)
# tensor(8.7053, dtype=torch.float64)
# tensor(8.7047, dtype=torch.float64)
# tensor(8.7042, dtype=torch.float64)
# tensor(8.7037, dtype=torch.float64)
# tensor(8.7032, dtype=torch.float64)
# tensor(8.7027, dtype=torch.float64)
# tensor(8.7022, dtype=torch.float64)
# training the nmf layer
# tensor(9.3236, dtype=torch.float64)
# training the classifier
# tensor(9.2309, dtype=torch.float64)
# tensor(9.1671, dtype=torch.float64)
# tensor(9.1613, dtype=torch.float64)
# tensor(9.1600, dtype=torch.float64)
# tensor(9.1591, dtype=torch.float64)
# tensor(9.1581, dtype=torch.float64)
# tensor(9.1572, dtype=torch.float64)
# tensor(9.1563, dtype=torch.float64)
# tensor(9.1554, dtype=torch.float64)
# tensor(9.1545, dtype=torch.float64)
# training the nmf layer
# tensor(9.2662, dtype=torch.float64)
# training the classifier
# tensor(9.1875, dtype=torch.float64)
# tensor(9.1194, dtype=torch.float64)
# tensor(9.1139, dtype=torch.float64)
# tensor(9.1124, dtype=torch.float64)
# tensor(9.1112, dtype=torch.float64)
# tensor(9.1100, dtype=torch.float64)
# tensor(9.1088, dtype=torch.float64)
# tensor(9.1076, dtype=torch.float64)
# tensor(9.1065, dtype=torch.float64)
# tensor(9.1054, dtype=torch.float64)
# training the nmf layer
# tensor(8.9268, dtype=torch.float64)
# training the classifier
# tensor(8.8395, dtype=torch.float64)
# tensor(8.7486, dtype=torch.float64)
# tensor(8.7444, dtype=torch.float64)
# tensor(8.7435, dtype=torch.float64)
# tensor(8.7426, dtype=torch.float64)
# tensor(8.7418, dtype=torch.float64)
# tensor(8.7410, dtype=torch.float64)
# tensor(8.7401, dtype=torch.float64)
# tensor(8.7393, dtype=torch.float64)
# tensor(8.7385, dtype=torch.float64)
# training the nmf layer
# tensor(9.3509, dtype=torch.float64)
# training the classifier
# tensor(9.2398, dtype=torch.float64)
# tensor(9.1527, dtype=torch.float64)
# tensor(9.1509, dtype=torch.float64)
# tensor(9.1500, dtype=torch.float64)
# tensor(9.1491, dtype=torch.float64)
# tensor(9.1482, dtype=torch.float64)
# tensor(9.1474, dtype=torch.float64)
# tensor(9.1465, dtype=torch.float64)
# tensor(9.1456, dtype=torch.float64)
# tensor(9.1448, dtype=torch.float64)
# training the nmf layer
# tensor(9.0880, dtype=torch.float64)
# training the classifier
# tensor(8.9834, dtype=torch.float64)
# tensor(8.9420, dtype=torch.float64)
# tensor(8.9402, dtype=torch.float64)
# tensor(8.9391, dtype=torch.float64)
# tensor(8.9380, dtype=torch.float64)
# tensor(8.9369, dtype=torch.float64)
# tensor(8.9358, dtype=torch.float64)
# tensor(8.9347, dtype=torch.float64)
# tensor(8.9336, dtype=torch.float64)
# tensor(8.9325, dtype=torch.float64)
# training the nmf layer
# tensor(9.1819, dtype=torch.float64)
# training the classifier
# tensor(9.0569, dtype=torch.float64)
# tensor(8.9914, dtype=torch.float64)
# tensor(8.9850, dtype=torch.float64)
# tensor(8.9828, dtype=torch.float64)
# tensor(8.9810, dtype=torch.float64)
# tensor(8.9792, dtype=torch.float64)
# tensor(8.9774, dtype=torch.float64)
# tensor(8.9756, dtype=torch.float64)
# tensor(8.9739, dtype=torch.float64)
# tensor(8.9722, dtype=torch.float64)
# training the nmf layer
# tensor(9.4174, dtype=torch.float64)
# training the classifier
# tensor(9.3245, dtype=torch.float64)
# tensor(9.2791, dtype=torch.float64)
# tensor(9.2763, dtype=torch.float64)
# tensor(9.2754, dtype=torch.float64)
# tensor(9.2746, dtype=torch.float64)
# tensor(9.2739, dtype=torch.float64)
# tensor(9.2731, dtype=torch.float64)
# tensor(9.2723, dtype=torch.float64)
# tensor(9.2715, dtype=torch.float64)
# tensor(9.2708, dtype=torch.float64)
# training the nmf layer
# tensor(9.4035, dtype=torch.float64)
# training the classifier
# tensor(9.2934, dtype=torch.float64)
# tensor(9.2571, dtype=torch.float64)
# tensor(9.2536, dtype=torch.float64)
# tensor(9.2525, dtype=torch.float64)
# tensor(9.2515, dtype=torch.float64)
# tensor(9.2506, dtype=torch.float64)
# tensor(9.2496, dtype=torch.float64)
# tensor(9.2487, dtype=torch.float64)
# tensor(9.2478, dtype=torch.float64)
# tensor(9.2468, dtype=torch.float64)
# training the nmf layer
# tensor(9.2763, dtype=torch.float64)
# training the classifier
# tensor(9.1832, dtype=torch.float64)
# tensor(9.1112, dtype=torch.float64)
# tensor(9.1033, dtype=torch.float64)
# tensor(9.1016, dtype=torch.float64)
# tensor(9.1006, dtype=torch.float64)
# tensor(9.0997, dtype=torch.float64)
# tensor(9.0988, dtype=torch.float64)
# tensor(9.0978, dtype=torch.float64)
# tensor(9.0969, dtype=torch.float64)
# tensor(9.0960, dtype=torch.float64)
# training the nmf layer
# tensor(9.0558, dtype=torch.float64)
# training the classifier
# tensor(8.9421, dtype=torch.float64)
# tensor(8.8611, dtype=torch.float64)
# tensor(8.8536, dtype=torch.float64)
# tensor(8.8517, dtype=torch.float64)
# tensor(8.8503, dtype=torch.float64)
# tensor(8.8489, dtype=torch.float64)
# tensor(8.8475, dtype=torch.float64)
# tensor(8.8462, dtype=torch.float64)
# tensor(8.8448, dtype=torch.float64)
# tensor(8.8435, dtype=torch.float64)
# training the nmf layer
# tensor(9.1535, dtype=torch.float64)
# training the classifier
# tensor(9.0610, dtype=torch.float64)
# tensor(8.9497, dtype=torch.float64)
# tensor(8.9444, dtype=torch.float64)
# tensor(8.9429, dtype=torch.float64)
# tensor(8.9415, dtype=torch.float64)
# tensor(8.9401, dtype=torch.float64)
# tensor(8.9387, dtype=torch.float64)
# tensor(8.9372, dtype=torch.float64)
# tensor(8.9359, dtype=torch.float64)
# tensor(8.9345, dtype=torch.float64)
# training the nmf layer
# tensor(9.1934, dtype=torch.float64)
# training the classifier
# tensor(9.1074, dtype=torch.float64)
# tensor(8.9841, dtype=torch.float64)
# tensor(8.9790, dtype=torch.float64)
# tensor(8.9774, dtype=torch.float64)
# tensor(8.9758, dtype=torch.float64)
# tensor(8.9742, dtype=torch.float64)
# tensor(8.9726, dtype=torch.float64)
# tensor(8.9711, dtype=torch.float64)
# tensor(8.9695, dtype=torch.float64)
# tensor(8.9680, dtype=torch.float64)
# training the nmf layer
# tensor(9.0283, dtype=torch.float64)
# training the classifier
# tensor(8.9161, dtype=torch.float64)
# tensor(8.8238, dtype=torch.float64)
# tensor(8.8175, dtype=torch.float64)
# tensor(8.8162, dtype=torch.float64)
# tensor(8.8152, dtype=torch.float64)
# tensor(8.8142, dtype=torch.float64)
# tensor(8.8132, dtype=torch.float64)
# tensor(8.8122, dtype=torch.float64)
# tensor(8.8112, dtype=torch.float64)
# tensor(8.8103, dtype=torch.float64)
# training the nmf layer
# tensor(9.0828, dtype=torch.float64)
# training the classifier
# tensor(8.9728, dtype=torch.float64)
# tensor(8.9051, dtype=torch.float64)
# tensor(8.9026, dtype=torch.float64)
# tensor(8.9013, dtype=torch.float64)
# tensor(8.9000, dtype=torch.float64)
# tensor(8.8987, dtype=torch.float64)
# tensor(8.8975, dtype=torch.float64)
# tensor(8.8962, dtype=torch.float64)
# tensor(8.8949, dtype=torch.float64)
# tensor(8.8937, dtype=torch.float64)
# training the nmf layer
# tensor(9.2075, dtype=torch.float64)
# training the classifier
# tensor(9.0872, dtype=torch.float64)
# tensor(8.9853, dtype=torch.float64)
# tensor(8.9811, dtype=torch.float64)
# tensor(8.9799, dtype=torch.float64)
# tensor(8.9788, dtype=torch.float64)
# tensor(8.9777, dtype=torch.float64)
# tensor(8.9766, dtype=torch.float64)
# tensor(8.9755, dtype=torch.float64)
# tensor(8.9744, dtype=torch.float64)
# tensor(8.9733, dtype=torch.float64)
# training the nmf layer
# tensor(8.8761, dtype=torch.float64)
# training the classifier
# tensor(8.7294, dtype=torch.float64)
# tensor(8.6293, dtype=torch.float64)
# tensor(8.6264, dtype=torch.float64)
# tensor(8.6245, dtype=torch.float64)
# tensor(8.6225, dtype=torch.float64)
# tensor(8.6206, dtype=torch.float64)
# tensor(8.6187, dtype=torch.float64)
# tensor(8.6168, dtype=torch.float64)
# tensor(8.6149, dtype=torch.float64)
# tensor(8.6131, dtype=torch.float64)
# training the nmf layer
# tensor(9.4851, dtype=torch.float64)
# training the classifier
# tensor(9.3545, dtype=torch.float64)
# tensor(9.2676, dtype=torch.float64)
# tensor(9.2640, dtype=torch.float64)
# tensor(9.2625, dtype=torch.float64)
# tensor(9.2610, dtype=torch.float64)
# tensor(9.2596, dtype=torch.float64)
# tensor(9.2581, dtype=torch.float64)
# tensor(9.2567, dtype=torch.float64)
# tensor(9.2553, dtype=torch.float64)
# tensor(9.2538, dtype=torch.float64)
# training the nmf layer
# tensor(8.9362, dtype=torch.float64)
# training the classifier
# tensor(8.8102, dtype=torch.float64)
# tensor(8.7372, dtype=torch.float64)
# tensor(8.7339, dtype=torch.float64)
# tensor(8.7321, dtype=torch.float64)
# tensor(8.7305, dtype=torch.float64)
# tensor(8.7288, dtype=torch.float64)
# tensor(8.7271, dtype=torch.float64)
# tensor(8.7254, dtype=torch.float64)
# tensor(8.7238, dtype=torch.float64)
# tensor(8.7221, dtype=torch.float64)
# training the nmf layer
# tensor(8.7107, dtype=torch.float64)
# training the classifier
# tensor(8.5385, dtype=torch.float64)
# tensor(8.4887, dtype=torch.float64)
# tensor(8.4856, dtype=torch.float64)
# tensor(8.4838, dtype=torch.float64)
# tensor(8.4820, dtype=torch.float64)
# tensor(8.4802, dtype=torch.float64)
# tensor(8.4785, dtype=torch.float64)
# tensor(8.4767, dtype=torch.float64)
# tensor(8.4749, dtype=torch.float64)
# tensor(8.4732, dtype=torch.float64)
# training the nmf layer
# tensor(9.3222, dtype=torch.float64)
# training the classifier
# tensor(9.1726, dtype=torch.float64)
# tensor(9.0792, dtype=torch.float64)
# tensor(9.0777, dtype=torch.float64)
# tensor(9.0763, dtype=torch.float64)
# tensor(9.0750, dtype=torch.float64)
# tensor(9.0738, dtype=torch.float64)
# tensor(9.0725, dtype=torch.float64)
# tensor(9.0712, dtype=torch.float64)
# tensor(9.0699, dtype=torch.float64)
# tensor(9.0686, dtype=torch.float64)
# training the nmf layer
# tensor(9.4911, dtype=torch.float64)
# training the classifier
# tensor(9.3424, dtype=torch.float64)
# tensor(9.2701, dtype=torch.float64)
# tensor(9.2669, dtype=torch.float64)
# tensor(9.2654, dtype=torch.float64)
# tensor(9.2639, dtype=torch.float64)
# tensor(9.2625, dtype=torch.float64)
# tensor(9.2610, dtype=torch.float64)
# tensor(9.2596, dtype=torch.float64)
# tensor(9.2581, dtype=torch.float64)
# tensor(9.2567, dtype=torch.float64)
# training the nmf layer
# tensor(9.0160, dtype=torch.float64)
# training the classifier
# tensor(8.8644, dtype=torch.float64)
# tensor(8.8075, dtype=torch.float64)
# tensor(8.8032, dtype=torch.float64)
# tensor(8.8018, dtype=torch.float64)
# tensor(8.8006, dtype=torch.float64)
# tensor(8.7994, dtype=torch.float64)
# tensor(8.7983, dtype=torch.float64)
# tensor(8.7971, dtype=torch.float64)
# tensor(8.7959, dtype=torch.float64)
# tensor(8.7948, dtype=torch.float64)
# training the nmf layer
# tensor(8.7919, dtype=torch.float64)
# training the classifier
# tensor(8.6378, dtype=torch.float64)
# tensor(8.5917, dtype=torch.float64)
# tensor(8.5896, dtype=torch.float64)
# tensor(8.5885, dtype=torch.float64)
# tensor(8.5875, dtype=torch.float64)
# tensor(8.5864, dtype=torch.float64)
# tensor(8.5854, dtype=torch.float64)
# tensor(8.5844, dtype=torch.float64)
# tensor(8.5833, dtype=torch.float64)
# tensor(8.5823, dtype=torch.float64)
# training the nmf layer
# tensor(9.0258, dtype=torch.float64)
# training the classifier
# tensor(8.8466, dtype=torch.float64)
# tensor(8.8230, dtype=torch.float64)
# tensor(8.8216, dtype=torch.float64)
# tensor(8.8203, dtype=torch.float64)
# tensor(8.8189, dtype=torch.float64)
# tensor(8.8176, dtype=torch.float64)
# tensor(8.8162, dtype=torch.float64)
# tensor(8.8149, dtype=torch.float64)
# tensor(8.8136, dtype=torch.float64)
# tensor(8.8123, dtype=torch.float64)
# training the nmf layer
# tensor(8.8033, dtype=torch.float64)
# training the classifier
# tensor(8.6321, dtype=torch.float64)
# tensor(8.5239, dtype=torch.float64)
# tensor(8.5152, dtype=torch.float64)
# tensor(8.5125, dtype=torch.float64)
# tensor(8.5101, dtype=torch.float64)
# tensor(8.5078, dtype=torch.float64)
# tensor(8.5054, dtype=torch.float64)
# tensor(8.5031, dtype=torch.float64)
# tensor(8.5008, dtype=torch.float64)
# tensor(8.4985, dtype=torch.float64)
# training the nmf layer
# tensor(9.1054, dtype=torch.float64)
# training the classifier
# tensor(8.9146, dtype=torch.float64)
# tensor(8.8383, dtype=torch.float64)
# tensor(8.8365, dtype=torch.float64)
# tensor(8.8349, dtype=torch.float64)
# tensor(8.8333, dtype=torch.float64)
# tensor(8.8317, dtype=torch.float64)
# tensor(8.8302, dtype=torch.float64)
# tensor(8.8286, dtype=torch.float64)
# tensor(8.8270, dtype=torch.float64)
# tensor(8.8255, dtype=torch.float64)
# training the nmf layer
# tensor(9.0632, dtype=torch.float64)
# training the classifier
# tensor(8.8624, dtype=torch.float64)
# tensor(8.8133, dtype=torch.float64)
# tensor(8.8108, dtype=torch.float64)
# tensor(8.8099, dtype=torch.float64)
# tensor(8.8090, dtype=torch.float64)
# tensor(8.8081, dtype=torch.float64)
# tensor(8.8072, dtype=torch.float64)
# tensor(8.8064, dtype=torch.float64)
# ...
# tensor(6.7962, dtype=torch.float64)
# tensor(6.7957, dtype=torch.float64)
# tensor(6.7951, dtype=torch.float64)
# training the nmf layer
# tensor(7.2340, dtype=torch.float64)
# training the classifier
# tensor(7.0129, dtype=torch.float64)
# tensor(6.9989, dtype=torch.float64)
# tensor(6.9918, dtype=torch.float64)
# tensor(6.9882, dtype=torch.float64)
# tensor(6.9862, dtype=torch.float64)
# tensor(6.9850, dtype=torch.float64)
# tensor(6.9843, dtype=torch.float64)
# tensor(6.9838, dtype=torch.float64)
# tensor(6.9833, dtype=torch.float64)
# tensor(6.9829, dtype=torch.float64)
# training the nmf layer
# tensor(7.1800, dtype=torch.float64)
# training the classifier
# tensor(6.8171, dtype=torch.float64)
# tensor(6.7977, dtype=torch.float64)
# tensor(6.7884, dtype=torch.float64)
# tensor(6.7837, dtype=torch.float64)
# tensor(6.7812, dtype=torch.float64)
# tensor(6.7796, dtype=torch.float64)
# tensor(6.7785, dtype=torch.float64)
# tensor(6.7775, dtype=torch.float64)
# tensor(6.7767, dtype=torch.float64)
# tensor(6.7759, dtype=torch.float64)
# training the nmf layer
# tensor(7.1344, dtype=torch.float64)
# training the classifier
# tensor(6.8741, dtype=torch.float64)
# tensor(6.8624, dtype=torch.float64)
# tensor(6.8563, dtype=torch.float64)
# tensor(6.8530, dtype=torch.float64)
# tensor(6.8511, dtype=torch.float64)
# tensor(6.8499, dtype=torch.float64)
# tensor(6.8490, dtype=torch.float64)
# tensor(6.8483, dtype=torch.float64)
# tensor(6.8477, dtype=torch.float64)
# tensor(6.8472, dtype=torch.float64)
# training the nmf layer
# tensor(7.1660, dtype=torch.float64)
# training the classifier
# tensor(6.8268, dtype=torch.float64)
# tensor(6.8106, dtype=torch.float64)
# tensor(6.8021, dtype=torch.float64)
# tensor(6.7975, dtype=torch.float64)
# tensor(6.7950, dtype=torch.float64)
# tensor(6.7935, dtype=torch.float64)
# tensor(6.7925, dtype=torch.float64)
# tensor(6.7917, dtype=torch.float64)
# tensor(6.7912, dtype=torch.float64)
# tensor(6.7906, dtype=torch.float64)
# training the nmf layer
# tensor(7.3667, dtype=torch.float64)
# training the classifier
# tensor(7.0456, dtype=torch.float64)
# tensor(7.0315, dtype=torch.float64)
# tensor(7.0248, dtype=torch.float64)
# tensor(7.0213, dtype=torch.float64)
# tensor(7.0194, dtype=torch.float64)
# tensor(7.0182, dtype=torch.float64)
# tensor(7.0173, dtype=torch.float64)
# tensor(7.0166, dtype=torch.float64)
# tensor(7.0159, dtype=torch.float64)
# tensor(7.0152, dtype=torch.float64)
# training the nmf layer
# tensor(6.8884, dtype=torch.float64)
# training the classifier
# tensor(6.6483, dtype=torch.float64)
# tensor(6.6164, dtype=torch.float64)
# tensor(6.6028, dtype=torch.float64)
# tensor(6.5968, dtype=torch.float64)
# tensor(6.5939, dtype=torch.float64)
# tensor(6.5924, dtype=torch.float64)
# tensor(6.5914, dtype=torch.float64)
# tensor(6.5907, dtype=torch.float64)
# tensor(6.5900, dtype=torch.float64)
# tensor(6.5894, dtype=torch.float64)
# training the nmf layer
# tensor(7.2831, dtype=torch.float64)
# training the classifier
# tensor(6.9914, dtype=torch.float64)
# tensor(6.9628, dtype=torch.float64)
# tensor(6.9486, dtype=torch.float64)
# tensor(6.9414, dtype=torch.float64)
# tensor(6.9378, dtype=torch.float64)
# tensor(6.9358, dtype=torch.float64)
# tensor(6.9346, dtype=torch.float64)
# tensor(6.9339, dtype=torch.float64)
# tensor(6.9334, dtype=torch.float64)
# tensor(6.9330, dtype=torch.float64)
# training the nmf layer
# tensor(6.7506, dtype=torch.float64)
# training the classifier
# tensor(6.5427, dtype=torch.float64)
# tensor(6.5225, dtype=torch.float64)
# tensor(6.5118, dtype=torch.float64)
# tensor(6.5061, dtype=torch.float64)
# tensor(6.5029, dtype=torch.float64)
# tensor(6.5010, dtype=torch.float64)
# tensor(6.4998, dtype=torch.float64)
# tensor(6.4990, dtype=torch.float64)
# tensor(6.4983, dtype=torch.float64)
# tensor(6.4977, dtype=torch.float64)
# training the nmf layer
# tensor(7.4592, dtype=torch.float64)
# training the classifier
# tensor(7.2144, dtype=torch.float64)
# tensor(7.1950, dtype=torch.float64)
# tensor(7.1857, dtype=torch.float64)
# tensor(7.1811, dtype=torch.float64)
# tensor(7.1788, dtype=torch.float64)
# tensor(7.1775, dtype=torch.float64)
# tensor(7.1767, dtype=torch.float64)
# tensor(7.1761, dtype=torch.float64)
# tensor(7.1757, dtype=torch.float64)
# tensor(7.1753, dtype=torch.float64)
# training the nmf layer
# tensor(7.3916, dtype=torch.float64)
# training the classifier
# tensor(7.1249, dtype=torch.float64)
# tensor(7.1047, dtype=torch.float64)
# tensor(7.0949, dtype=torch.float64)
# tensor(7.0900, dtype=torch.float64)
# tensor(7.0875, dtype=torch.float64)
# tensor(7.0860, dtype=torch.float64)
# tensor(7.0850, dtype=torch.float64)
# tensor(7.0843, dtype=torch.float64)
# tensor(7.0837, dtype=torch.float64)
# tensor(7.0831, dtype=torch.float64)
# training the nmf layer
# tensor(7.1848, dtype=torch.float64)
# training the classifier
# tensor(6.8842, dtype=torch.float64)
# tensor(6.8699, dtype=torch.float64)
# tensor(6.8622, dtype=torch.float64)
# tensor(6.8581, dtype=torch.float64)
# tensor(6.8556, dtype=torch.float64)
# tensor(6.8541, dtype=torch.float64)
# tensor(6.8530, dtype=torch.float64)
# tensor(6.8522, dtype=torch.float64)
# tensor(6.8515, dtype=torch.float64)
# tensor(6.8509, dtype=torch.float64)
# training the nmf layer
# tensor(6.8813, dtype=torch.float64)
# training the classifier
# tensor(6.5990, dtype=torch.float64)
# tensor(6.5764, dtype=torch.float64)
# tensor(6.5650, dtype=torch.float64)
# tensor(6.5593, dtype=torch.float64)
# tensor(6.5563, dtype=torch.float64)
# tensor(6.5547, dtype=torch.float64)
# tensor(6.5538, dtype=torch.float64)
# tensor(6.5532, dtype=torch.float64)
# tensor(6.5528, dtype=torch.float64)
# tensor(6.5525, dtype=torch.float64)
# training the nmf layer
# tensor(7.2791, dtype=torch.float64)
# training the classifier
# tensor(6.9972, dtype=torch.float64)
# tensor(6.9698, dtype=torch.float64)
# tensor(6.9565, dtype=torch.float64)
# tensor(6.9498, dtype=torch.float64)
# tensor(6.9460, dtype=torch.float64)
# tensor(6.9437, dtype=torch.float64)
# tensor(6.9420, dtype=torch.float64)
# tensor(6.9406, dtype=torch.float64)
# tensor(6.9394, dtype=torch.float64)
# tensor(6.9382, dtype=torch.float64)
# epoch =  4
#  tensor(1373.6465, dtype=torch.float64)
# training the nmf layer
# tensor(7.3876, dtype=torch.float64)
# training the classifier
# tensor(7.1195, dtype=torch.float64)
# tensor(7.0881, dtype=torch.float64)
# tensor(7.0724, dtype=torch.float64)
# tensor(7.0644, dtype=torch.float64)
# tensor(7.0601, dtype=torch.float64)
# tensor(7.0576, dtype=torch.float64)
# tensor(7.0560, dtype=torch.float64)
# tensor(7.0548, dtype=torch.float64)
# tensor(7.0539, dtype=torch.float64)
# tensor(7.0531, dtype=torch.float64)
# training the nmf layer
# tensor(7.4917, dtype=torch.float64)
# training the classifier
# tensor(7.3001, dtype=torch.float64)
# tensor(7.2841, dtype=torch.float64)
# tensor(7.2762, dtype=torch.float64)
# tensor(7.2722, dtype=torch.float64)
# tensor(7.2701, dtype=torch.float64)
# tensor(7.2689, dtype=torch.float64)
# tensor(7.2682, dtype=torch.float64)
# tensor(7.2676, dtype=torch.float64)
# tensor(7.2672, dtype=torch.float64)
# tensor(7.2668, dtype=torch.float64)
# training the nmf layer
# tensor(7.5180, dtype=torch.float64)
# training the classifier
# tensor(7.3545, dtype=torch.float64)
# tensor(7.3367, dtype=torch.float64)
# tensor(7.3269, dtype=torch.float64)
# tensor(7.3214, dtype=torch.float64)
# tensor(7.3182, dtype=torch.float64)
# tensor(7.3161, dtype=torch.float64)
# tensor(7.3146, dtype=torch.float64)
# tensor(7.3135, dtype=torch.float64)
# tensor(7.3126, dtype=torch.float64)
# tensor(7.3117, dtype=torch.float64)
# training the nmf layer
# tensor(6.8648, dtype=torch.float64)
# training the classifier
# tensor(6.6556, dtype=torch.float64)
# tensor(6.6050, dtype=torch.float64)
# tensor(6.5833, dtype=torch.float64)
# tensor(6.5738, dtype=torch.float64)
# tensor(6.5695, dtype=torch.float64)
# tensor(6.5674, dtype=torch.float64)
# tensor(6.5662, dtype=torch.float64)
# tensor(6.5654, dtype=torch.float64)
# tensor(6.5648, dtype=torch.float64)
# tensor(6.5643, dtype=torch.float64)
# training the nmf layer
# tensor(7.4691, dtype=torch.float64)
# training the classifier
# tensor(7.3067, dtype=torch.float64)
# tensor(7.2793, dtype=torch.float64)
# tensor(7.2645, dtype=torch.float64)
# tensor(7.2564, dtype=torch.float64)
# tensor(7.2519, dtype=torch.float64)
# tensor(7.2493, dtype=torch.float64)
# tensor(7.2478, dtype=torch.float64)
# tensor(7.2467, dtype=torch.float64)
# tensor(7.2460, dtype=torch.float64)
# tensor(7.2454, dtype=torch.float64)
# training the nmf layer
# tensor(7.0501, dtype=torch.float64)
# training the classifier
# tensor(6.7835, dtype=torch.float64)
# tensor(6.7536, dtype=torch.float64)
# tensor(6.7395, dtype=torch.float64)
# tensor(6.7326, dtype=torch.float64)
# tensor(6.7291, dtype=torch.float64)
# tensor(6.7272, dtype=torch.float64)
# tensor(6.7260, dtype=torch.float64)
# tensor(6.7251, dtype=torch.float64)
# tensor(6.7244, dtype=torch.float64)
# tensor(6.7238, dtype=torch.float64)
# training the nmf layer
# tensor(7.4148, dtype=torch.float64)
# training the classifier
# tensor(7.2072, dtype=torch.float64)
# tensor(7.1914, dtype=torch.float64)
# tensor(7.1829, dtype=torch.float64)
# tensor(7.1781, dtype=torch.float64)
# tensor(7.1753, dtype=torch.float64)
# tensor(7.1735, dtype=torch.float64)
# tensor(7.1723, dtype=torch.float64)
# tensor(7.1714, dtype=torch.float64)
# tensor(7.1706, dtype=torch.float64)
# tensor(7.1699, dtype=torch.float64)
# training the nmf layer
# tensor(7.1307, dtype=torch.float64)
# training the classifier
# tensor(6.8896, dtype=torch.float64)
# tensor(6.8665, dtype=torch.float64)
# tensor(6.8551, dtype=torch.float64)
# tensor(6.8494, dtype=torch.float64)
# tensor(6.8464, dtype=torch.float64)
# tensor(6.8448, dtype=torch.float64)
# tensor(6.8438, dtype=torch.float64)
# tensor(6.8430, dtype=torch.float64)
# tensor(6.8425, dtype=torch.float64)
# tensor(6.8420, dtype=torch.float64)
# training the nmf layer
# tensor(7.4647, dtype=torch.float64)
# training the classifier
# tensor(7.2669, dtype=torch.float64)
# tensor(7.2639, dtype=torch.float64)
# tensor(7.2622, dtype=torch.float64)
# tensor(7.2612, dtype=torch.float64)
# tensor(7.2606, dtype=torch.float64)
# tensor(7.2602, dtype=torch.float64)
# tensor(7.2598, dtype=torch.float64)
# tensor(7.2596, dtype=torch.float64)
# tensor(7.2593, dtype=torch.float64)
# tensor(7.2591, dtype=torch.float64)
# training the nmf layer
# tensor(6.6560, dtype=torch.float64)
# training the classifier
# tensor(6.4439, dtype=torch.float64)
# tensor(6.4178, dtype=torch.float64)
# tensor(6.4063, dtype=torch.float64)
# tensor(6.4012, dtype=torch.float64)
# tensor(6.3988, dtype=torch.float64)
# tensor(6.3975, dtype=torch.float64)
# tensor(6.3968, dtype=torch.float64)
# tensor(6.3963, dtype=torch.float64)
# tensor(6.3958, dtype=torch.float64)
# tensor(6.3955, dtype=torch.float64)
# training the nmf layer
# tensor(7.0799, dtype=torch.float64)
# training the classifier
# tensor(6.8618, dtype=torch.float64)
# tensor(6.8465, dtype=torch.float64)
# tensor(6.8390, dtype=torch.float64)
# tensor(6.8352, dtype=torch.float64)
# tensor(6.8332, dtype=torch.float64)
# tensor(6.8321, dtype=torch.float64)
# tensor(6.8314, dtype=torch.float64)
# tensor(6.8309, dtype=torch.float64)
# tensor(6.8305, dtype=torch.float64)
# tensor(6.8302, dtype=torch.float64)
# training the nmf layer
# tensor(7.0915, dtype=torch.float64)
# training the classifier
# tensor(6.9084, dtype=torch.float64)
# tensor(6.9022, dtype=torch.float64)
# tensor(6.8989, dtype=torch.float64)
# tensor(6.8969, dtype=torch.float64)
# tensor(6.8958, dtype=torch.float64)
# tensor(6.8951, dtype=torch.float64)
# tensor(6.8945, dtype=torch.float64)
# tensor(6.8941, dtype=torch.float64)
# tensor(6.8937, dtype=torch.float64)
# tensor(6.8934, dtype=torch.float64)
# training the nmf layer
# tensor(7.1973, dtype=torch.float64)
# training the classifier
# tensor(6.9918, dtype=torch.float64)
# tensor(6.9579, dtype=torch.float64)
# tensor(6.9415, dtype=torch.float64)
# tensor(6.9334, dtype=torch.float64)
# tensor(6.9291, dtype=torch.float64)
# tensor(6.9267, dtype=torch.float64)
# tensor(6.9251, dtype=torch.float64)
# tensor(6.9239, dtype=torch.float64)
# tensor(6.9229, dtype=torch.float64)
# tensor(6.9221, dtype=torch.float64)
# training the nmf layer
# tensor(7.3366, dtype=torch.float64)
# training the classifier
# tensor(7.1093, dtype=torch.float64)
# tensor(7.0959, dtype=torch.float64)
# tensor(7.0890, dtype=torch.float64)
# tensor(7.0853, dtype=torch.float64)
# tensor(7.0832, dtype=torch.float64)
# tensor(7.0821, dtype=torch.float64)
# tensor(7.0813, dtype=torch.float64)
# tensor(7.0808, dtype=torch.float64)
# tensor(7.0804, dtype=torch.float64)
# tensor(7.0801, dtype=torch.float64)
# training the nmf layer
# tensor(7.2568, dtype=torch.float64)
# training the classifier
# tensor(7.0873, dtype=torch.float64)
# tensor(7.0814, dtype=torch.float64)
# tensor(7.0781, dtype=torch.float64)
# tensor(7.0761, dtype=torch.float64)
# tensor(7.0748, dtype=torch.float64)
# tensor(7.0738, dtype=torch.float64)
# tensor(7.0730, dtype=torch.float64)
# tensor(7.0723, dtype=torch.float64)
# tensor(7.0716, dtype=torch.float64)
# tensor(7.0710, dtype=torch.float64)
# training the nmf layer
# tensor(7.1147, dtype=torch.float64)
# training the classifier
# tensor(6.9141, dtype=torch.float64)
# tensor(6.8933, dtype=torch.float64)
# tensor(6.8825, dtype=torch.float64)
# tensor(6.8767, dtype=torch.float64)
# tensor(6.8735, dtype=torch.float64)
# tensor(6.8715, dtype=torch.float64)
# tensor(6.8702, dtype=torch.float64)
# tensor(6.8693, dtype=torch.float64)
# tensor(6.8685, dtype=torch.float64)
# tensor(6.8678, dtype=torch.float64)
# training the nmf layer
# tensor(6.5109, dtype=torch.float64)
# training the classifier
# tensor(6.2980, dtype=torch.float64)
# tensor(6.2669, dtype=torch.float64)
# tensor(6.2510, dtype=torch.float64)
# tensor(6.2427, dtype=torch.float64)
# tensor(6.2384, dtype=torch.float64)
# tensor(6.2359, dtype=torch.float64)
# tensor(6.2345, dtype=torch.float64)
# tensor(6.2335, dtype=torch.float64)
# tensor(6.2328, dtype=torch.float64)
# tensor(6.2322, dtype=torch.float64)
# training the nmf layer
# tensor(7.0670, dtype=torch.float64)
# training the classifier
# tensor(6.8576, dtype=torch.float64)
# tensor(6.8333, dtype=torch.float64)
# tensor(6.8220, dtype=torch.float64)
# tensor(6.8165, dtype=torch.float64)
# tensor(6.8138, dtype=torch.float64)
# tensor(6.8123, dtype=torch.float64)
# tensor(6.8114, dtype=torch.float64)
# tensor(6.8108, dtype=torch.float64)
# tensor(6.8102, dtype=torch.float64)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-6c727f102c50> in <module>()
#      33         for k in range(10):
#      34             net.zero_grad()
# ---> 35             S_lst,pred = net(inputs)
#      36             loss = loss_func(net, inputs, S_lst,pred,label,l_batch)
#      37             loss.backward()
#
# C:\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# ~\Dropbox\Deep NMF\Code\Cathy Code\Full Backprop Package\deep_nmf.ipynb in forward(self, X)
#
# C:\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# ~\Dropbox\Deep NMF\Code\Cathy Code\Full Backprop Package\lsqnonneg_module.ipynb in forward(self, input)
#
# ~\Dropbox\Deep NMF\Code\Cathy Code\Full Backprop Package\lsqnonneg_module.ipynb in forward(ctx, input, A)
#
# ~\Dropbox\Deep NMF\Code\Cathy Code\Full Backprop Package\lsqnonneg_module.ipynb in lsqnonneg_tensor_version(C, D)
#
# C:\Anaconda3\lib\site-packages\scipy\optimize\nnls.py in nnls(A, b, maxiter)
#      41     """
#      42
# ---> 43     A, b = map(asarray_chkfinite, (A, b))
#      44
#      45     if len(A.shape) != 2:
#
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py in asarray_chkfinite(a, dtype, order)
#    1229     """
#    1230     a = asarray(a, dtype=dtype, order=order)
# -> 1231     if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
#    1232         raise ValueError(
#    1233             "array must not contain infs or NaNs")
#
# KeyboardInterrupt:

# %%
plt.plot(total_loss_lst)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-906ece0314d3> in <module>()
# ----> 1 plt.plot(total_loss_lst)
#       2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
# SAVE YOUR RESULT!!!!!
A = net.lsqnonneglst[0].A.data
B = net.linear.weight.data
A_np = A.numpy()
B_np = B.numpy()
np.save('semi_90_A', A_np)
np.save('semi_90_B', B_np)

# %%
# Doing forward propagation on the whole dataset, remember to SAVE S and prod!
def get_whole_output(net, dataset, param_lst = None):
    history = Writer()
    # initialize the network with certain initial value
    if param_lst is not None:
        for (i,param) in enumerate(net.parameters()):
            param.data = param_lst[i]
    # start to forward propagate, 100 at a time
    n = len(dataset)
    if n%100 == 0:
        batch_num = n/100
    else:
        batch_num = n//100 + 1
    print('batch_num = ', batch_num, '\n')
    for i in range(batch_num):
        print('current at batch:', i)
        try:
            (inputs, label, l_batch) = dataset[i*100:(i+1)*100]
        except:
            (inputs, label, l_batch) = dataset[i*100:]
        history.add_tensor('label', label)
        output, pred = net(inputs)
        history.add_tensor('output', output)
        history.add_tensor('pred', pred)
    return history

# %%
history = get_whole_output(net, dataset)

# %%
A_np = np.load('semi_90_A')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c6ebef6b1a89> in <module>()
# ----> 1 A_np = np.load('semi_90_A')
#
# NameError: name 'np' is not defined
